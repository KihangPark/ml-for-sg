# %%
# Set root package root directory.
import os
os.environ['ML_FOR_SG_ROOT'] = 'Z:\Dev\Github\ml-for-sg'

# Create shotgun data manager.
from lib.source_generator.shotgun.source_generator import ShotgunSourceGenerator
shotgun_source_generator = ShotgunSourceGenerator()

# %%
shotgun_source_generator.source_schema
print shotgun_source_generator.handler
# Out:
# <shotgun_api3.shotgun.Shotgun object at 0x000000000DB93780>

# %%
# Get target list.
source = shotgun_source_generator.get_raw_source(project_id=70, limit=400)

# %%
# Generate filter for project.
filters = [[
    'project', 'is', {
        'type': 'Project',
        'id': 70}
], ['code', 'is', 'bunny_010_0010']]

# Get source data from shotgun.
schema_field_list = shotgun_source_generator.handler.schema_field_read('Shot')
sources = shotgun_source_generator.handler.find(
    'Shot',
    filters,
    schema_field_list.keys(),
    limit=50
)

valid_sources = []
for source in sources:
    # Filter out improper project source.
    if not source['project']:
        continue
    valid_sources.append(source)

source = valid_sources

# %%
# Register dummy tag / description to shotgun.
from lib.utils.dummy_data_generation import (
    register_sample_sg_data, 
    register_heavy_feature_tag
)
register_sample_sg_data(shotgun_source_generator.handler, source,shotgun_source_generator.generator_config)
register_heavy_feature_tag(shotgun_source_generator.handler, source)
# Out:
# ---------------------------------------------------------------------------
# Fault                                     Traceback (most recent call last)
# <ipython-input-16-39cb91be9a56> in <module>()
#       4     register_heavy_feature_tag
#       5 )
# ----> 6 register_sample_sg_data(shotgun_source_generator.handler, source,shotgun_source_generator.generator_config)
#       7 register_heavy_feature_tag(shotgun_source_generator.handler, source)
#
# Z:\Dev\Github\ml-for-sg\lib\utils\dummy_data_generation.pyc in register_sample_sg_data(handler, source, generator_config)
#      45         }
#      46
# ---> 47         #handler.update('Task', single_source['id'], data)
#      48         handler.update('Shot', single_source['id'], data)
#      49
#
# Z:\Dev\python-api\shotgun_api3\shotgun.pyc in update(self, entity_type, entity_id, data, multi_entity_update_modes)
#    1294                         multi_entity_update_modes, "multi_entity_update_mode"))
#    1295             }
# -> 1296             record = self._call_rpc("update", params)
#    1297             result = self._parse_records(record)[0]
#    1298         else:
#
# Z:\Dev\python-api\shotgun_api3\shotgun.pyc in _call_rpc(self, method, params, include_auth_params, first)
#    3082
#    3083         response = self._decode_response(resp_headers, body)
# -> 3084         self._response_errors(response)
#    3085         response = self._transform_inbound(response)
#    3086
#
# Z:\Dev\python-api\shotgun_api3\shotgun.pyc in _response_errors(self, sg_response)
#    3373             else:
#    3374                 # raise general Fault
# -> 3375                 raise Fault(sg_response.get("message", "Unknown Error"))
#    3376         return
#    3377
#
# Fault: API update() CRUD ERROR #3: Entity of type [Task] with id=862 does not exist.

# %%
from abc import ABCMeta, abstractmethod

# %%
class TestParent(object):
    __meta__ = ABCMeta
    def __init__(self):
        print 'aa'
        self.test_config = 'nice'
    @abstractmethod
    def test(self):
        raise NotImplementedError
class TestChild(TestParent):
    def __init__(self):
        super(TestChild, self).__init__()
        print 'bb'
        print self.test_config
    def test(self):
        print 'test'

# %%
a = TestChild()
# Out:
# aa
# bb
# nice

# %%
shotgun_source_generator.convert_source_to_panda_data('test')
shotgun_source_generator.cost
# Out:
# 'time_logs_sum'

# %%
df_all = shotgun_source_generator.convert_source_to_panda_data('test')

# %%
MOCKED_SOURCE = {'abt1180': {'open_notes_count': 110, 'code': 'abt1180', 'tasks': 'anim - anim, comp - comp, dmp - window dmp, layout - layout_assembly, light - light, paint - paint, roto - roto, stereo - stereo, techanim - fur.sim, techanim - suit.sim, track - camera_track_mp_v0001, track - QC_Screens', 'sg_status_stereo': 'apr', 'cached_display_name': 'abt1180', 'sg_working_duration': 190, 'created_by': 'Kat Gore', 'sg_status_list': 'fin', 'sg_sequence': 'abt', 'type': 'Shot', 'sg_turnover': 'TO_005', 'sg_cut_in': 1009, 'updated_by': 'Tom Luna', 'sg_cut_out': 1182, 'sg_script_location': 'Sc 35F Cam D', 'sg_ctd_percentage': 100, 'sg_vfx_description': u'benetar,cg,clean,comp,cosmetic,extension,fix,fx,gs,interactive,light,paint,quill,rocket,seatbelts,up,wig', 'assets': 'char.rocket, prop.benatar.seatbelt', 'sg_work_out': 1190, 'sg_bid_note': u'and,are,because,but,cheddar,cheese,doing,efforts,for,get,give,is,it,little,maybe,nice,our,quill,re,rocket,that,us,we,whoever,why,will', 'project': 'Mary Lou', 'sg_work_in': 1001, 'sg_final_due_date': '2018-03-09', 'sg_assumptions': 'TEAM A', 'sg_shot_length': 190, 'cost': 18.125, 'sg_cut_duration': 174, 'id': 37238, 'sg_head_handle': 8, 'sg_client_name': 'ABT1180', 'sg_disk_status': 'act', 'tags': 'AllSpice, beat_1, Brad ADR ref, Rocket, Team_A, TO_005', 'sg_editorial_grade': 'abt1180_plates_mp_v0001', 'sg_render_resolution': '.25', 'sg_validation_list': 'act', 'sg_client_version': 21, 'sg_camera_lens_mm': '135mm (UP135-02)', 'sg_turnover_date': '2017-08-02', 'sg_cut_order': 6, 'sg_good_for_temp': True, 'sg_reel': '2', 'sg_assigned_to': 'Mark Derksen', 'sg_tail_handle': 8, 'sg_primary_location': 'Los Angeles'}, 'abt1080': {'open_notes_count': 377, 'code': 'abt1080', 'tasks': 'anim - anim, comp - cgfg, comp - comp, dmp - window dmp, fx - jumpspace, layout - layout_assembly, light - light, matchmove - 100%_char_Mantis_head, paint - paint, roto - roto, roto - roto rocket, stereo - stereo, techanim - fur sim, techanim - suit sim, track - camera_track_mp_v0001, track - char_single_frame_line_up, track - line_up_screens', 'sg_status_stereo': 'apr', 'cached_display_name': 'abt1080', 'sg_working_duration': 695, 'created_by': 'Julie Osborn', 'sg_status_list': 'fin', 'sg_sequence': 'abt', 'sg_sticky_note': u'dtt1020', 'type': 'Shot', 'sg_turnover': 'TO_003', 'sg_cut_in': 1009, 'updated_by': 'Tom Luna', 'sg_cut_out': 1687, 'sg_script_location': 'Sc 35 Cam D', 'sg_ctd_percentage': 100, 'sg_vfx_description': u'antennae,benetar,cg,color,comp,costume,drax,environment,extension,eyelid,eyes,fix,fixes,fx,game,gamora,glass,graphics,groot,gs,handheld,interactive,jump,light,mantis,quill,raccoon,rocket,seatbelts,set,space,teen,video,wig,windshield', 'sg_camera_lens_mm': '50mm (UP50-01)', 'sg_work_out': 1695, 'sg_bid_note': u'adolescent,and,drax,flight,game,gamora,groot,handheld,in,mantis,plays,quill,rocket,seats,sit,their,video', 'project': 'Mary Lou', 'sg_work_in': 1001, 'sg_final_due_date': '2018-03-16', 'sg_assumptions': 'TEAM A', 'sg_shot_length': 695, 'cost': 35.329166666666666, 'sg_cut_duration': 679, 'id': 33183, 'sg_bid_name': 'GT1080', 'sg_head_handle': 8, 'sg_overscan': 1.12, 'sg_client_name': 'ABT1080', 'sg_disk_status': 'na', 'tags': 'AllSpice, AllSpice_keyshots, beat_1, Brad ADR ref, keyshot, Rocket, Team_A, TO_003', 'sg_editorial_grade': 'abt1080_plates_mp_v0001', 'sg_render_resolution': '.5', 'sg_validation_list': 'act', 'sg_client_version': 19, 'assets': 'char.groot, char.mantis, char.mantis.antennae, char.rocket, prop.benatar.seatbelt, prop.game.defender', 'sg_turnover_date': '2017-05-04', 'sg_cut_order': 4, 'sg_reel': '2', 'sg_tail_handle': 8, 'sg_primary_location': 'Los Angeles'}, 'abt1160': {'updated_by': 'Julie Osborn', 'sg_turnover': 'TO_003', 'open_notes_count': 16, 'code': 'abt1160', 'sg_sticky_note': u'dtt1060', 'tags': 'AllSpice, beat_1, Brad ADR ref, TO_003', 'sg_shot_length': 97, 'sg_cut_out': 1089, 'sg_cut_in': 1009, 'sg_turnover_date': '2017-05-04', 'sg_script_location': 'Sc 35D Cam D', 'sg_ctd_percentage': 30, 'cost': 2.125, 'sg_bid_note': u'are,blank,but,doing,get,huh,it,rocket,stares,that,uh,we,why', 'sg_status_stereo': 'na', 'sg_status_list': 'omt', 'sg_cut_duration': 81, 'cached_display_name': 'abt1160', 'sg_vfx_description': u'benetar,cg,clean,comp,extension,fx,game,glass,groot,gs,handheld,interactive,light,paint,raccoon,rocket,seatbelts,set,teen,up,video,windshield', 'id': 33185, 'sg_render_resolution': '.5', 'sg_bid_name': 'GT1160', 'sg_work_out': 1097, 'sg_validation_list': 'act', 'sg_client_version': 1, 'assets': 'char.groot, char.rocket, prop.benatar.seatbelt, prop.game.defender', 'sg_head_handle': 8, 'tasks': 'comp - comp, layout - layout_assembly, light - light, paint - paint, roto - roto, techanim - fur sim, techanim - suit sim, track - camera_track_mp_v0001, track - line_up_screens, track - single_frame_line_up_Groot_Chair, track - single_frame_line_up_Rocket_Chair', 'sg_camera_lens_mm': '135mm (UP135-02)', 'sg_working_duration': 97, 'sg_editorial_grade': 'abt1160_plates_mp_v0001', 'created_by': 'Julie Osborn', 'project': 'Mary Lou', 'parent_shots': 'abt2570', 'sg_overscan': 1.09, 'sg_client_name': 'ABT1160', 'sg_tail_handle': 8, 'sg_disk_status': 'na', 'sg_work_in': 1001, 'type': 'Shot', 'sg_primary_location': 'Los Angeles'}}

# %%
MOCKED_SOURCE
# Out:
# {'abt1080': {'assets': 'char.groot, char.mantis, char.mantis.antennae, char.rocket, prop.benatar.seatbelt, prop.game.defender',
#   'cached_display_name': 'abt1080',
#   'code': 'abt1080',
#   'cost': 35.329166666666666,
#   'created_by': 'Julie Osborn',
#   'id': 33183,
#   'open_notes_count': 377,
#   'project': 'Mary Lou',
#   'sg_assumptions': 'TEAM A',
#   'sg_bid_name': 'GT1080',
#   'sg_bid_note': u'adolescent,and,drax,flight,game,gamora,groot,handheld,in,mantis,plays,quill,rocket,seats,sit,their,video',
#   'sg_camera_lens_mm': '50mm (UP50-01)',
#   'sg_client_name': 'ABT1080',
#   'sg_client_version': 19,
#   'sg_ctd_percentage': 100,
#   'sg_cut_duration': 679,
#   'sg_cut_in': 1009,
#   'sg_cut_order': 4,
#   'sg_cut_out': 1687,
#   'sg_disk_status': 'na',
#   'sg_editorial_grade': 'abt1080_plates_mp_v0001',
#   'sg_final_due_date': '2018-03-16',
#   'sg_head_handle': 8,
#   'sg_overscan': 1.12,
#   'sg_primary_location': 'Los Angeles',
#   'sg_reel': '2',
#   'sg_render_resolution': '.5',
#   'sg_script_location': 'Sc 35 Cam D',
#   'sg_sequence': 'abt',
#   'sg_shot_length': 695,
#   'sg_status_list': 'fin',
#   'sg_status_stereo': 'apr',
#   'sg_sticky_note': u'dtt1020',
#   'sg_tail_handle': 8,
#   'sg_turnover': 'TO_003',
#   'sg_turnover_date': '2017-05-04',
#   'sg_validation_list': 'act',
#   'sg_vfx_description': u'antennae,benetar,cg,color,comp,costume,drax,environment,extension,eyelid,eyes,fix,fixes,fx,game,gamora,glass,graphics,groot,gs,handheld,interactive,jump,light,mantis,quill,raccoon,rocket,seatbelts,set,space,teen,video,wig,windshield',
#   'sg_work_in': 1001,
#   'sg_work_out': 1695,
#   'sg_working_duration': 695,
#   'tags': 'AllSpice, AllSpice_keyshots, beat_1, Brad ADR ref, keyshot, Rocket, Team_A, TO_003',
#   'tasks': 'anim - anim, comp - cgfg, comp - comp, dmp - window dmp, fx - jumpspace, layout - layout_assembly, light - light, matchmove - 100%_char_Mantis_head, paint - paint, roto - roto, roto - roto rocket, stereo - stereo, techanim - fur sim, techanim - suit sim, track - camera_track_mp_v0001, track - char_single_frame_line_up, track - line_up_screens',
#   'type': 'Shot',
#   'updated_by': 'Tom Luna'},
#  'abt1160': {'assets': 'char.groot, char.rocket, prop.benatar.seatbelt, prop.game.defender',
#   'cached_display_name': 'abt1160',
#   'code': 'abt1160',
#   'cost': 2.125,
#   'created_by': 'Julie Osborn',
#   'id': 33185,
#   'open_notes_count': 16,
#   'parent_shots': 'abt2570',
#   'project': 'Mary Lou',
#   'sg_bid_name': 'GT1160',
#   'sg_bid_note': u'are,blank,but,doing,get,huh,it,rocket,stares,that,uh,we,why',
#   'sg_camera_lens_mm': '135mm (UP135-02)',
#   'sg_client_name': 'ABT1160',
#   'sg_client_version': 1,
#   'sg_ctd_percentage': 30,
#   'sg_cut_duration': 81,
#   'sg_cut_in': 1009,
#   'sg_cut_out': 1089,
#   'sg_disk_status': 'na',
#   'sg_editorial_grade': 'abt1160_plates_mp_v0001',
#   'sg_head_handle': 8,
#   'sg_overscan': 1.09,
#   'sg_primary_location': 'Los Angeles',
#   'sg_render_resolution': '.5',
#   'sg_script_location': 'Sc 35D Cam D',
#   'sg_shot_length': 97,
#   'sg_status_list': 'omt',
#   'sg_status_stereo': 'na',
#   'sg_sticky_note': u'dtt1060',
#   'sg_tail_handle': 8,
#   'sg_turnover': 'TO_003',
#   'sg_turnover_date': '2017-05-04',
#   'sg_validation_list': 'act',
#   'sg_vfx_description': u'benetar,cg,clean,comp,extension,fx,game,glass,groot,gs,handheld,interactive,light,paint,raccoon,rocket,seatbelts,set,teen,up,video,windshield',
#   'sg_work_in': 1001,
#   'sg_work_out': 1097,
#   'sg_working_duration': 97,
#   'tags': 'AllSpice, beat_1, Brad ADR ref, TO_003',
#   'tasks': 'comp - comp, layout - layout_assembly, light - light, paint - paint, roto - roto, techanim - fur sim, techanim - suit sim, track - camera_track_mp_v0001, track - line_up_screens, track - single_frame_line_up_Groot_Chair, track - single_frame_line_up_Rocket_Chair',
#   'type': 'Shot',
#   'updated_by': 'Julie Osborn'},
#  'abt1180': {'assets': 'char.rocket, prop.benatar.seatbelt',
#   'cached_display_name': 'abt1180',
#   'code': 'abt1180',
#   'cost': 18.125,
#   'created_by': 'Kat Gore',
#   'id': 37238,
#   'open_notes_count': 110,
#   'project': 'Mary Lou',
#   'sg_assigned_to': 'Mark Derksen',
#   'sg_assumptions': 'TEAM A',
#   'sg_bid_note': u'and,are,because,but,cheddar,cheese,doing,efforts,for,get,give,is,it,little,maybe,nice,our,quill,re,rocket,that,us,we,whoever,why,will',
#   'sg_camera_lens_mm': '135mm (UP135-02)',
#   'sg_client_name': 'ABT1180',
#   'sg_client_version': 21,
#   'sg_ctd_percentage': 100,
#   'sg_cut_duration': 174,
#   'sg_cut_in': 1009,
#   'sg_cut_order': 6,
#   'sg_cut_out': 1182,
#   'sg_disk_status': 'act',
#   'sg_editorial_grade': 'abt1180_plates_mp_v0001',
#   'sg_final_due_date': '2018-03-09',
#   'sg_good_for_temp': True,
#   'sg_head_handle': 8,
#   'sg_primary_location': 'Los Angeles',
#   'sg_reel': '2',
#   'sg_render_resolution': '.25',
#   'sg_script_location': 'Sc 35F Cam D',
#   'sg_sequence': 'abt',
#   'sg_shot_length': 190,
#   'sg_status_list': 'fin',
#   'sg_status_stereo': 'apr',
#   'sg_tail_handle': 8,
#   'sg_turnover': 'TO_005',
#   'sg_turnover_date': '2017-08-02',
#   'sg_validation_list': 'act',
#   'sg_vfx_description': u'benetar,cg,clean,comp,cosmetic,extension,fix,fx,gs,interactive,light,paint,quill,rocket,seatbelts,up,wig',
#   'sg_work_in': 1001,
#   'sg_work_out': 1190,
#   'sg_working_duration': 190,
#   'tags': 'AllSpice, beat_1, Brad ADR ref, Rocket, Team_A, TO_005',
#   'tasks': 'anim - anim, comp - comp, dmp - window dmp, layout - layout_assembly, light - light, paint - paint, roto - roto, stereo - stereo, techanim - fur.sim, techanim - suit.sim, track - camera_track_mp_v0001, track - QC_Screens',
#   'type': 'Shot',
#   'updated_by': 'Tom Luna'}}

# %%
sample_shot = shot_dict[shot_dict.keys()[0]]
column_arange = sorted(sample_shot.keys())

all_column_dict = {}
for column in column_arange:
    all_column_value = []
    all_column = []
    for key, value in shot_dict.iteritems():
        if column in value.keys() and ',' in str(value[column]):
            all_column.extend(value[column].split(','))
        elif column in value.keys():
            if type(value[column]) == int or type(value[column]) == float:
                continue
            else:
                all_column.append(value[column])
        else:
            continue
    all_column = sorted(list(set(all_column)))
    all_column_dict.update({column: all_column})

print all_column_dict    
count = 0
heatmap = []
df_x_full = None
df_y_full = None
shot_cost_list = []
index_list = []
for shot, shot_value in shot_dict.iteritems():
    index_list.append(shot)
    shot_cost_list.append(shot_value['cost'])
df_y_full = pd.DataFrame(shot_cost_list, index=index_list, columns=['cost'])
for column, column_value in all_column_dict.iteritems():
    count += 1
    #if count > 3:
    #    break
    print column
    if column == 'cost':
        continue
    shot_cost_list = []
    if not column_value:
        index_list = []
        value_list = []
        for shot, shot_value in shot_dict.iteritems():
            index_list.append(shot)
            shot_cost_list.append(shot_value['cost'])
            if column in shot_value.keys():
                value_list.append(shot_value[column])
            else:
                value_list.append(0)
        df_x = pd.DataFrame(value_list, index=index_list, columns=[column])
        df_y = pd.DataFrame(shot_cost_list, index=index_list, columns=['cost'])
        df_all = pd.concat([df_x, df_y], axis=1)
        df_x_full = pd.concat([df_x_full, df_x], axis=1)
        #df_y_full = df_y
    else:
        index_list = []
        value_list = []
        shot_cost_list = []
        for shot, shot_value in shot_dict.iteritems():
            shot_cost_list.append(shot_value['cost'])
            if shot_value.has_key(column):
                if ',' in str(shot_value[column]):
                    shot_column_value_list = shot_value[column].split(',')
                else:
                    shot_column_value_list = [shot_value[column]]
            else:
                shot_column_value_list = []

            index_list.append(shot)
            shot_value = []
            for single_column_value in column_value:
                if single_column_value in shot_column_value_list:
                    shot_value.append(1)
                else:
                    shot_value.append(0)
            value_list.append(shot_value)
        df_x = pd.DataFrame(value_list, index=index_list, columns=column_value)
        df_y = pd.DataFrame(shot_cost_list, index=index_list, columns=['cost'])
        df_all = pd.concat([df_x, df_y], axis=1)
        df_x_full = pd.concat([df_x_full, df_x], axis=1)
        #df_y_full = df_y
    print df_all
    print df_all.corr()
    heatmap.append(df_all.corr())
    print '----------------------------------------'
    print df_x_full
    print '----------------------------------------'
    #sns.heatmap(df_all.corr())

df_complete = pd.concat([df_x_full, df_y_full], axis=1)
print '================================='
print df_complete
print '================================='
'''
fig,axn = plt.subplots(len(heatmap), 1, figsize=(15,500))

count = 0
for ax in axn.flat: 
    sns.heatmap(heatmap[count], ax=ax)
    count += 1
'''

# %%
source = MOCKED_SOURCE
sorted_columns = sorted(source[source.keys()[0]].keys())

# Gather string values.
all_column_dict = {}
for column in sorted_columns:
    values = []
    for _, single_source_value in source.iteritems():
        if column in single_source_value.keys() and ',' in str(single_source_value[column]):
            values.extend([x.strip() for x in single_source_value[column].split(',')])
        elif column in single_source_value.keys():
            if type(single_source_value[column]) == str:
                values.append(single_source_value[column].strip())
    values = sorted(set(values))
    all_column_dict.update({column: values})
all_column_dict
# Out:
# {'assets': ['char.groot',
#   'char.mantis',
#   'char.mantis.antennae',
#   'char.rocket',
#   'prop.benatar.seatbelt',
#   'prop.game.defender'],
#  'cached_display_name': ['abt1080', 'abt1160', 'abt1180'],
#  'code': ['abt1080', 'abt1160', 'abt1180'],
#  'cost': [],
#  'created_by': ['Julie Osborn', 'Kat Gore'],
#  'id': [],
#  'open_notes_count': [],
#  'project': ['Mary Lou'],
#  'sg_assigned_to': ['Mark Derksen'],
#  'sg_assumptions': ['TEAM A'],
#  'sg_bid_note': [u'adolescent',
#   u'and',
#   u'are',
#   u'because',
#   u'blank',
#   u'but',
#   u'cheddar',
#   u'cheese',
#   u'doing',
#   u'drax',
#   u'efforts',
#   u'flight',
#   u'for',
#   u'game',
#   u'gamora',
#   u'get',
#   u'give',
#   u'groot',
#   u'handheld',
#   u'huh',
#   u'in',
#   u'is',
#   u'it',
#   u'little',
#   u'mantis',
#   u'maybe',
#   u'nice',
#   u'our',
#   u'plays',
#   u'quill',
#   u're',
#   u'rocket',
#   u'seats',
#   u'sit',
#   u'stares',
#   u'that',
#   u'their',
#   u'uh',
#   u'us',
#   u'video',
#   u'we',
#   u'whoever',
#   u'why',
#   u'will'],
#  'sg_camera_lens_mm': ['135mm (UP135-02)', '50mm (UP50-01)'],
#  'sg_client_name': ['ABT1080', 'ABT1160', 'ABT1180'],
#  'sg_client_version': [],
#  'sg_ctd_percentage': [],
#  'sg_cut_duration': [],
#  'sg_cut_in': [],
#  'sg_cut_order': [],
#  'sg_cut_out': [],
#  'sg_disk_status': ['act', 'na'],
#  'sg_editorial_grade': ['abt1080_plates_mp_v0001',
#   'abt1160_plates_mp_v0001',
#   'abt1180_plates_mp_v0001'],
#  'sg_final_due_date': ['2018-03-09', '2018-03-16'],
#  'sg_good_for_temp': [],
#  'sg_head_handle': [],
#  'sg_primary_location': ['Los Angeles'],
#  'sg_reel': ['2'],
#  'sg_render_resolution': ['.25', '.5'],
#  'sg_script_location': ['Sc 35 Cam D', 'Sc 35D Cam D', 'Sc 35F Cam D'],
#  'sg_sequence': ['abt'],
#  'sg_shot_length': [],
#  'sg_status_list': ['fin', 'omt'],
#  'sg_status_stereo': ['apr', 'na'],
#  'sg_tail_handle': [],
#  'sg_turnover': ['TO_003', 'TO_005'],
#  'sg_turnover_date': ['2017-05-04', '2017-08-02'],
#  'sg_validation_list': ['act'],
#  'sg_vfx_description': [u'antennae',
#   u'benetar',
#   u'cg',
#   u'clean',
#   u'color',
#   u'comp',
#   u'cosmetic',
#   u'costume',
#   u'drax',
#   u'environment',
#   u'extension',
#   u'eyelid',
#   u'eyes',
#   u'fix',
#   u'fixes',
#   u'fx',
#   u'game',
#   u'gamora',
#   u'glass',
#   u'graphics',
#   u'groot',
#   u'gs',
#   u'handheld',
#   u'interactive',
#   u'jump',
#   u'light',
#   u'mantis',
#   u'paint',
#   u'quill',
#   u'raccoon',
#   u'rocket',
#   u'seatbelts',
#   u'set',
#   u'space',
#   u'teen',
#   u'up',
#   u'video',
#   u'wig',
#   u'windshield'],
#  'sg_work_in': [],
#  'sg_work_out': [],
#  'sg_working_duration': [],
#  'tags': ['AllSpice',
#   'AllSpice_keyshots',
#   'Brad ADR ref',
#   'Rocket',
#   'TO_003',
#   'TO_005',
#   'Team_A',
#   'beat_1',
#   'keyshot'],
#  'tasks': ['anim - anim',
#   'comp - cgfg',
#   'comp - comp',
#   'dmp - window dmp',
#   'fx - jumpspace',
#   'layout - layout_assembly',
#   'light - light',
#   'matchmove - 100%_char_Mantis_head',
#   'paint - paint',
#   'roto - roto',
#   'roto - roto rocket',
#   'stereo - stereo',
#   'techanim - fur sim',
#   'techanim - fur.sim',
#   'techanim - suit sim',
#   'techanim - suit.sim',
#   'track - QC_Screens',
#   'track - camera_track_mp_v0001',
#   'track - char_single_frame_line_up',
#   'track - line_up_screens',
#   'track - single_frame_line_up_Groot_Chair',
#   'track - single_frame_line_up_Rocket_Chair'],
#  'type': ['Shot'],
#  'updated_by': ['Julie Osborn', 'Tom Luna']}

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_y_full = None
source = MOCKED_SOURCE
source_costs = []
indexes = []
for key in sorted(source):
    single_source = source[key]
    indexes.append(key)
    source_costs.append(single_source['cost'])
df_y_full = pd.DataFrame(source_costs, index=indexes, columns=['cost'])

# %%
df_y_full
# Out:
#               cost
# abt1080  35.329167
# abt1160   2.125000
# abt1180  18.125000

# %%
heatmap = []
#all_column_dict = {}
df_x_full = None
for column, column_values in all_column_dict.iteritems():
    if column == 'cost':
        continue
    indexes = []
    values = []
    if not column_values:
        # Column value does not contains string list.
        for key in sorted(source):
            single_source = source[key]
            indexes.append(key)
            if column in single_source.keys():
                values.append(single_source[column])
            else:
                values.append(0)
        df_x = pd.DataFrame(values, index=indexes, columns=[column])
        df_x_full = pd.concat([df_x_full, df_x], axis=1)
    else:
        # Column value contains string list.
        for key in sorted(source):
            single_source = source[key]
            if single_source.has_key(column):
                if ',' in str(single_source[column]):
                    single_source_column_values = [x.strip() for x in single_source[column].split(',')]
                else:
                    single_source_column_values = [single_source[column]]
            else:
                single_source_column_values = []
            indexes.append(key)
            source_values = []
            for column_value in column_values:
                if column_value in single_source_column_values:
                    source_values.append(1)
                else:
                    source_values.append(0)
            values.append(source_values)
        df_x = pd.DataFrame(values, index=indexes, columns=column_values)
        df_x_full = pd.concat([df_x_full, df_x], axis=1)
    # Generate single pair data frame for calculating heatmap.
    df_all = pd.concat([df_x, df_y_full], axis=1)
    print 'df_all : '
    print df_all
    print df_all.corr()
    heatmap.append(df_all.corr())
    #sns.heatmap(df_all.corr())

print 'df_complete :'
df_complete = pd.concat([df_x_full, df_y_full], axis=1)
# Out:
# df_all :
#          open_notes_count       cost
# abt1080               377  35.329167
# abt1160                16   2.125000
# abt1180               110  18.125000
#                   open_notes_count      cost
# open_notes_count          1.000000  0.969161
# cost                      0.969161  1.000000
# df_all :
#          abt1080  abt1160  abt1180       cost
# abt1080        1        0        0  35.329167
# abt1160        0        1        0   2.125000
# abt1180        0        0        1  18.125000
#           abt1080   abt1160   abt1180      cost
# abt1080  1.000000 -0.500000 -0.500000  0.876302
# abt1160 -0.500000  1.000000 -0.500000 -0.855369
# abt1180 -0.500000 -0.500000  1.000000 -0.020933
# cost     0.876302 -0.855369 -0.020933  1.000000
# df_all :
#          2018-03-09  2018-03-16       cost
# abt1080           0           1  35.329167
# abt1160           0           0   2.125000
# abt1180           1           0  18.125000
#             2018-03-09  2018-03-16      cost
# 2018-03-09    1.000000   -0.500000 -0.020933
# 2018-03-16   -0.500000    1.000000  0.876302
# cost         -0.020933    0.876302  1.000000
# df_all :
#          TEAM A       cost
# abt1080       1  35.329167
# abt1160       0   2.125000
# abt1180       1  18.125000
#           TEAM A      cost
# TEAM A  1.000000  0.855369
# cost    0.855369  1.000000
# df_all :
#          sg_shot_length       cost
# abt1080             695  35.329167
# abt1160              97   2.125000
# abt1180             190  18.125000
#                 sg_shot_length      cost
# sg_shot_length        1.000000  0.936722
# cost                  0.936722  1.000000
# df_all :
#          sg_cut_order       cost
# abt1080             4  35.329167
# abt1160             0   2.125000
# abt1180             6  18.125000
#               sg_cut_order      cost
# sg_cut_order      1.000000  0.638686
# cost              0.638686  1.000000
# df_all :
#          apr  na       cost
# abt1080    1   0  35.329167
# abt1160    0   1   2.125000
# abt1180    1   0  18.125000
#            apr        na      cost
# apr   1.000000 -1.000000  0.855369
# na   -1.000000  1.000000 -0.855369
# cost  0.855369 -0.855369  1.000000
# df_all :
#          sg_cut_duration       cost
# abt1080              679  35.329167
# abt1160               81   2.125000
# abt1180              174  18.125000
#                  sg_cut_duration      cost
# sg_cut_duration         1.000000  0.936722
# cost                    0.936722  1.000000
# df_all :
#          abt1080  abt1160  abt1180       cost
# abt1080        1        0        0  35.329167
# abt1160        0        1        0   2.125000
# abt1180        0        0        1  18.125000
#           abt1080   abt1160   abt1180      cost
# abt1080  1.000000 -0.500000 -0.500000  0.876302
# abt1160 -0.500000  1.000000 -0.500000 -0.855369
# abt1180 -0.500000 -0.500000  1.000000 -0.020933
# cost     0.876302 -0.855369 -0.020933  1.000000
# df_all :
#             id       cost
# abt1080  33183  35.329167
# abt1160  33185   2.125000
# abt1180  37238  18.125000
#            id     cost
# id    1.00000 -0.02136
# cost -0.02136  1.00000
# df_all :
#          Julie Osborn  Tom Luna       cost
# abt1080             0         1  35.329167
# abt1160             1         0   2.125000
# abt1180             0         1  18.125000
#               Julie Osborn  Tom Luna      cost
# Julie Osborn      1.000000 -1.000000 -0.855369
# Tom Luna         -1.000000  1.000000  0.855369
# cost             -0.855369  0.855369  1.000000
# df_all :
#          sg_head_handle       cost
# abt1080               8  35.329167
# abt1160               8   2.125000
# abt1180               8  18.125000
#                 sg_head_handle  cost
# sg_head_handle             NaN   NaN
# cost                       NaN   1.0
# df_all :
#          anim - anim  comp - cgfg  comp - comp  dmp - window dmp  \
# abt1080            1            1            1                 1
# abt1160            0            0            1                 0
# abt1180            1            0            1                 1
#
#          fx - jumpspace  layout - layout_assembly  light - light  \
# abt1080               1                         1              1
# abt1160               0                         1              1
# abt1180               0                         1              1
#
#          matchmove - 100%_char_Mantis_head  paint - paint  roto - roto  \
# abt1080                                  1              1            1
# abt1160                                  0              1            1
# abt1180                                  0              1            1
#
#            ...      techanim - fur.sim  techanim - suit sim  \
# abt1080    ...                       0                    1
# abt1160    ...                       0                    1
# abt1180    ...                       1                    0
#
#          techanim - suit.sim  track - QC_Screens  \
# abt1080                    0                   0
# abt1160                    0                   0
# abt1180                    1                   1
#
#          track - camera_track_mp_v0001  track - char_single_frame_line_up  \
# abt1080                              1                                  1
# abt1160                              1                                  0
# abt1180                              1                                  0
#
#          track - line_up_screens  track - single_frame_line_up_Groot_Chair  \
# abt1080                        1                                         0
# abt1160                        1                                         1
# abt1180                        0                                         0
#
#          track - single_frame_line_up_Rocket_Chair       cost
# abt1080                                          0  35.329167
# abt1160                                          1   2.125000
# abt1180                                          0  18.125000
#
# [3 rows x 23 columns]
#                                            anim - anim  comp - cgfg  \
# anim - anim                                   1.000000     0.500000
# comp - cgfg                                   0.500000     1.000000
# comp - comp                                        NaN          NaN
# dmp - window dmp                              1.000000     0.500000
# fx - jumpspace                                0.500000     1.000000
# layout - layout_assembly                           NaN          NaN
# light - light                                      NaN          NaN
# matchmove - 100%_char_Mantis_head             0.500000     1.000000
# paint - paint                                      NaN          NaN
# roto - roto                                        NaN          NaN
# roto - roto rocket                            0.500000     1.000000
# stereo - stereo                               1.000000     0.500000
# techanim - fur sim                           -0.500000     0.500000
# techanim - fur.sim                            0.500000    -0.500000
# techanim - suit sim                          -0.500000     0.500000
# techanim - suit.sim                           0.500000    -0.500000
# track - QC_Screens                            0.500000    -0.500000
# track - camera_track_mp_v0001                      NaN          NaN
# track - char_single_frame_line_up             0.500000     1.000000
# track - line_up_screens                      -0.500000     0.500000
# track - single_frame_line_up_Groot_Chair     -1.000000    -0.500000
# track - single_frame_line_up_Rocket_Chair    -1.000000    -0.500000
# cost                                          0.855369     0.876302
#
#                                            comp - comp  dmp - window dmp  \
# anim - anim                                        NaN          1.000000
# comp - cgfg                                        NaN          0.500000
# comp - comp                                        NaN               NaN
# dmp - window dmp                                   NaN          1.000000
# fx - jumpspace                                     NaN          0.500000
# layout - layout_assembly                           NaN               NaN
# light - light                                      NaN               NaN
# matchmove - 100%_char_Mantis_head                  NaN          0.500000
# paint - paint                                      NaN               NaN
# roto - roto                                        NaN               NaN
# roto - roto rocket                                 NaN          0.500000
# stereo - stereo                                    NaN          1.000000
# techanim - fur sim                                 NaN         -0.500000
# techanim - fur.sim                                 NaN          0.500000
# techanim - suit sim                                NaN         -0.500000
# techanim - suit.sim                                NaN          0.500000
# track - QC_Screens                                 NaN          0.500000
# track - camera_track_mp_v0001                      NaN               NaN
# track - char_single_frame_line_up                  NaN          0.500000
# track - line_up_screens                            NaN         -0.500000
# track - single_frame_line_up_Groot_Chair           NaN         -1.000000
# track - single_frame_line_up_Rocket_Chair          NaN         -1.000000
# cost                                               NaN          0.855369
#
#                                            fx - jumpspace  \
# anim - anim                                      0.500000
# comp - cgfg                                      1.000000
# comp - comp                                           NaN
# dmp - window dmp                                 0.500000
# fx - jumpspace                                   1.000000
# layout - layout_assembly                              NaN
# light - light                                         NaN
# matchmove - 100%_char_Mantis_head                1.000000
# paint - paint                                         NaN
# roto - roto                                           NaN
# roto - roto rocket                               1.000000
# stereo - stereo                                  0.500000
# techanim - fur sim                               0.500000
# techanim - fur.sim                              -0.500000
# techanim - suit sim                              0.500000
# techanim - suit.sim                             -0.500000
# track - QC_Screens                              -0.500000
# track - camera_track_mp_v0001                         NaN
# track - char_single_frame_line_up                1.000000
# track - line_up_screens                          0.500000
# track - single_frame_line_up_Groot_Chair        -0.500000
# track - single_frame_line_up_Rocket_Chair       -0.500000
# cost                                             0.876302
#
#                                            layout - layout_assembly  \
# anim - anim                                                     NaN
# comp - cgfg                                                     NaN
# comp - comp                                                     NaN
# dmp - window dmp                                                NaN
# fx - jumpspace                                                  NaN
# layout - layout_assembly                                        NaN
# light - light                                                   NaN
# matchmove - 100%_char_Mantis_head                               NaN
# paint - paint                                                   NaN
# roto - roto                                                     NaN
# roto - roto rocket                                              NaN
# stereo - stereo                                                 NaN
# techanim - fur sim                                              NaN
# techanim - fur.sim                                              NaN
# techanim - suit sim                                             NaN
# techanim - suit.sim                                             NaN
# track - QC_Screens                                              NaN
# track - camera_track_mp_v0001                                   NaN
# track - char_single_frame_line_up                               NaN
# track - line_up_screens                                         NaN
# track - single_frame_line_up_Groot_Chair                        NaN
# track - single_frame_line_up_Rocket_Chair                       NaN
# cost                                                            NaN
#
#                                            light - light  \
# anim - anim                                          NaN
# comp - cgfg                                          NaN
# comp - comp                                          NaN
# dmp - window dmp                                     NaN
# fx - jumpspace                                       NaN
# layout - layout_assembly                             NaN
# light - light                                        NaN
# matchmove - 100%_char_Mantis_head                    NaN
# paint - paint                                        NaN
# roto - roto                                          NaN
# roto - roto rocket                                   NaN
# stereo - stereo                                      NaN
# techanim - fur sim                                   NaN
# techanim - fur.sim                                   NaN
# techanim - suit sim                                  NaN
# techanim - suit.sim                                  NaN
# track - QC_Screens                                   NaN
# track - camera_track_mp_v0001                        NaN
# track - char_single_frame_line_up                    NaN
# track - line_up_screens                              NaN
# track - single_frame_line_up_Groot_Chair             NaN
# track - single_frame_line_up_Rocket_Chair            NaN
# cost                                                 NaN
#
#                                            matchmove - 100%_char_Mantis_head  \
# anim - anim                                                         0.500000
# comp - cgfg                                                         1.000000
# comp - comp                                                              NaN
# dmp - window dmp                                                    0.500000
# fx - jumpspace                                                      1.000000
# layout - layout_assembly                                                 NaN
# light - light                                                            NaN
# matchmove - 100%_char_Mantis_head                                   1.000000
# paint - paint                                                            NaN
# roto - roto                                                              NaN
# roto - roto rocket                                                  1.000000
# stereo - stereo                                                     0.500000
# techanim - fur sim                                                  0.500000
# techanim - fur.sim                                                 -0.500000
# techanim - suit sim                                                 0.500000
# techanim - suit.sim                                                -0.500000
# track - QC_Screens                                                 -0.500000
# track - camera_track_mp_v0001                                            NaN
# track - char_single_frame_line_up                                   1.000000
# track - line_up_screens                                             0.500000
# track - single_frame_line_up_Groot_Chair                           -0.500000
# track - single_frame_line_up_Rocket_Chair                          -0.500000
# cost                                                                0.876302
#
#                                            paint - paint  roto - roto  \
# anim - anim                                          NaN          NaN
# comp - cgfg                                          NaN          NaN
# comp - comp                                          NaN          NaN
# dmp - window dmp                                     NaN          NaN
# fx - jumpspace                                       NaN          NaN
# layout - layout_assembly                             NaN          NaN
# light - light                                        NaN          NaN
# matchmove - 100%_char_Mantis_head                    NaN          NaN
# paint - paint                                        NaN          NaN
# roto - roto                                          NaN          NaN
# roto - roto rocket                                   NaN          NaN
# stereo - stereo                                      NaN          NaN
# techanim - fur sim                                   NaN          NaN
# techanim - fur.sim                                   NaN          NaN
# techanim - suit sim                                  NaN          NaN
# techanim - suit.sim                                  NaN          NaN
# track - QC_Screens                                   NaN          NaN
# track - camera_track_mp_v0001                        NaN          NaN
# track - char_single_frame_line_up                    NaN          NaN
# track - line_up_screens                              NaN          NaN
# track - single_frame_line_up_Groot_Chair             NaN          NaN
# track - single_frame_line_up_Rocket_Chair            NaN          NaN
# cost                                                 NaN          NaN
#
#                                              ...     techanim - fur.sim  \
# anim - anim                                  ...               0.500000
# comp - cgfg                                  ...              -0.500000
# comp - comp                                  ...                    NaN
# dmp - window dmp                             ...               0.500000
# fx - jumpspace                               ...              -0.500000
# layout - layout_assembly                     ...                    NaN
# light - light                                ...                    NaN
# matchmove - 100%_char_Mantis_head            ...              -0.500000
# paint - paint                                ...                    NaN
# roto - roto                                  ...                    NaN
# roto - roto rocket                           ...              -0.500000
# stereo - stereo                              ...               0.500000
# techanim - fur sim                           ...              -1.000000
# techanim - fur.sim                           ...               1.000000
# techanim - suit sim                          ...              -1.000000
# techanim - suit.sim                          ...               1.000000
# track - QC_Screens                           ...               1.000000
# track - camera_track_mp_v0001                ...                    NaN
# track - char_single_frame_line_up            ...              -0.500000
# track - line_up_screens                      ...              -1.000000
# track - single_frame_line_up_Groot_Chair     ...              -0.500000
# track - single_frame_line_up_Rocket_Chair    ...              -0.500000
# cost                                         ...              -0.020933
#
#                                            techanim - suit sim  \
# anim - anim                                          -0.500000
# comp - cgfg                                           0.500000
# comp - comp                                                NaN
# dmp - window dmp                                     -0.500000
# fx - jumpspace                                        0.500000
# layout - layout_assembly                                   NaN
# light - light                                              NaN
# matchmove - 100%_char_Mantis_head                     0.500000
# paint - paint                                              NaN
# roto - roto                                                NaN
# roto - roto rocket                                    0.500000
# stereo - stereo                                      -0.500000
# techanim - fur sim                                    1.000000
# techanim - fur.sim                                   -1.000000
# techanim - suit sim                                   1.000000
# techanim - suit.sim                                  -1.000000
# track - QC_Screens                                   -1.000000
# track - camera_track_mp_v0001                              NaN
# track - char_single_frame_line_up                     0.500000
# track - line_up_screens                               1.000000
# track - single_frame_line_up_Groot_Chair              0.500000
# track - single_frame_line_up_Rocket_Chair             0.500000
# cost                                                  0.020933
#
#                                            techanim - suit.sim  \
# anim - anim                                           0.500000
# comp - cgfg                                          -0.500000
# comp - comp                                                NaN
# dmp - window dmp                                      0.500000
# fx - jumpspace                                       -0.500000
# layout - layout_assembly                                   NaN
# light - light                                              NaN
# matchmove - 100%_char_Mantis_head                    -0.500000
# paint - paint                                              NaN
# roto - roto                                                NaN
# roto - roto rocket                                   -0.500000
# stereo - stereo                                       0.500000
# techanim - fur sim                                   -1.000000
# techanim - fur.sim                                    1.000000
# techanim - suit sim                                  -1.000000
# techanim - suit.sim                                   1.000000
# track - QC_Screens                                    1.000000
# track - camera_track_mp_v0001                              NaN
# track - char_single_frame_line_up                    -0.500000
# track - line_up_screens                              -1.000000
# track - single_frame_line_up_Groot_Chair             -0.500000
# track - single_frame_line_up_Rocket_Chair            -0.500000
# cost                                                 -0.020933
#
#                                            track - QC_Screens  \
# anim - anim                                          0.500000
# comp - cgfg                                         -0.500000
# comp - comp                                               NaN
# dmp - window dmp                                     0.500000
# fx - jumpspace                                      -0.500000
# layout - layout_assembly                                  NaN
# light - light                                             NaN
# matchmove - 100%_char_Mantis_head                   -0.500000
# paint - paint                                             NaN
# roto - roto                                               NaN
# roto - roto rocket                                  -0.500000
# stereo - stereo                                      0.500000
# techanim - fur sim                                  -1.000000
# techanim - fur.sim                                   1.000000
# techanim - suit sim                                 -1.000000
# techanim - suit.sim                                  1.000000
# track - QC_Screens                                   1.000000
# track - camera_track_mp_v0001                             NaN
# track - char_single_frame_line_up                   -0.500000
# track - line_up_screens                             -1.000000
# track - single_frame_line_up_Groot_Chair            -0.500000
# track - single_frame_line_up_Rocket_Chair           -0.500000
# cost                                                -0.020933
#
#                                            track - camera_track_mp_v0001  \
# anim - anim                                                          NaN
# comp - cgfg                                                          NaN
# comp - comp                                                          NaN
# dmp - window dmp                                                     NaN
# fx - jumpspace                                                       NaN
# layout - layout_assembly                                             NaN
# light - light                                                        NaN
# matchmove - 100%_char_Mantis_head                                    NaN
# paint - paint                                                        NaN
# roto - roto                                                          NaN
# roto - roto rocket                                                   NaN
# stereo - stereo                                                      NaN
# techanim - fur sim                                                   NaN
# techanim - fur.sim                                                   NaN
# techanim - suit sim                                                  NaN
# techanim - suit.sim                                                  NaN
# track - QC_Screens                                                   NaN
# track - camera_track_mp_v0001                                        NaN
# track - char_single_frame_line_up                                    NaN
# track - line_up_screens                                              NaN
# track - single_frame_line_up_Groot_Chair                             NaN
# track - single_frame_line_up_Rocket_Chair                            NaN
# cost                                                                 NaN
#
#                                            track - char_single_frame_line_up  \
# anim - anim                                                         0.500000
# comp - cgfg                                                         1.000000
# comp - comp                                                              NaN
# dmp - window dmp                                                    0.500000
# fx - jumpspace                                                      1.000000
# layout - layout_assembly                                                 NaN
# light - light                                                            NaN
# matchmove - 100%_char_Mantis_head                                   1.000000
# paint - paint                                                            NaN
# roto - roto                                                              NaN
# roto - roto rocket                                                  1.000000
# stereo - stereo                                                     0.500000
# techanim - fur sim                                                  0.500000
# techanim - fur.sim                                                 -0.500000
# techanim - suit sim                                                 0.500000
# techanim - suit.sim                                                -0.500000
# track - QC_Screens                                                 -0.500000
# track - camera_track_mp_v0001                                            NaN
# track - char_single_frame_line_up                                   1.000000
# track - line_up_screens                                             0.500000
# track - single_frame_line_up_Groot_Chair                           -0.500000
# track - single_frame_line_up_Rocket_Chair                          -0.500000
# cost                                                                0.876302
#
#                                            track - line_up_screens  \
# anim - anim                                              -0.500000
# comp - cgfg                                               0.500000
# comp - comp                                                    NaN
# dmp - window dmp                                         -0.500000
# fx - jumpspace                                            0.500000
# layout - layout_assembly                                       NaN
# light - light                                                  NaN
# matchmove - 100%_char_Mantis_head                         0.500000
# paint - paint                                                  NaN
# roto - roto                                                    NaN
# roto - roto rocket                                        0.500000
# stereo - stereo                                          -0.500000
# techanim - fur sim                                        1.000000
# techanim - fur.sim                                       -1.000000
# techanim - suit sim                                       1.000000
# techanim - suit.sim                                      -1.000000
# track - QC_Screens                                       -1.000000
# track - camera_track_mp_v0001                                  NaN
# track - char_single_frame_line_up                         0.500000
# track - line_up_screens                                   1.000000
# track - single_frame_line_up_Groot_Chair                  0.500000
# track - single_frame_line_up_Rocket_Chair                 0.500000
# cost                                                      0.020933
#
#                                            track - single_frame_line_up_Groot_Chair  \
# anim - anim                                                               -1.000000
# comp - cgfg                                                               -0.500000
# comp - comp                                                                     NaN
# dmp - window dmp                                                          -1.000000
# fx - jumpspace                                                            -0.500000
# layout - layout_assembly                                                        NaN
# light - light                                                                   NaN
# matchmove - 100%_char_Mantis_head                                         -0.500000
# paint - paint                                                                   NaN
# roto - roto                                                                     NaN
# roto - roto rocket                                                        -0.500000
# stereo - stereo                                                           -1.000000
# techanim - fur sim                                                         0.500000
# techanim - fur.sim                                                        -0.500000
# techanim - suit sim                                                        0.500000
# techanim - suit.sim                                                       -0.500000
# track - QC_Screens                                                        -0.500000
# track - camera_track_mp_v0001                                                   NaN
# track - char_single_frame_line_up                                         -0.500000
# track - line_up_screens                                                    0.500000
# track - single_frame_line_up_Groot_Chair                                   1.000000
# track - single_frame_line_up_Rocket_Chair                                  1.000000
# cost                                                                      -0.855369
#
#                                            track - single_frame_line_up_Rocket_Chair  \
# anim - anim                                                                -1.000000
# comp - cgfg                                                                -0.500000
# comp - comp                                                                      NaN
# dmp - window dmp                                                           -1.000000
# fx - jumpspace                                                             -0.500000
# layout - layout_assembly                                                         NaN
# light - light                                                                    NaN
# matchmove - 100%_char_Mantis_head                                          -0.500000
# paint - paint                                                                    NaN
# roto - roto                                                                      NaN
# roto - roto rocket                                                         -0.500000
# stereo - stereo                                                            -1.000000
# techanim - fur sim                                                          0.500000
# techanim - fur.sim                                                         -0.500000
# techanim - suit sim                                                         0.500000
# techanim - suit.sim                                                        -0.500000
# track - QC_Screens                                                         -0.500000
# track - camera_track_mp_v0001                                                    NaN
# track - char_single_frame_line_up                                          -0.500000
# track - line_up_screens                                                     0.500000
# track - single_frame_line_up_Groot_Chair                                    1.000000
# track - single_frame_line_up_Rocket_Chair                                   1.000000
# cost                                                                       -0.855369
#
#                                                cost
# anim - anim                                0.855369
# comp - cgfg                                0.876302
# comp - comp                                     NaN
# dmp - window dmp                           0.855369
# fx - jumpspace                             0.876302
# layout - layout_assembly                        NaN
# light - light                                   NaN
# matchmove - 100%_char_Mantis_head          0.876302
# paint - paint                                   NaN
# roto - roto                                     NaN
# roto - roto rocket                         0.876302
# stereo - stereo                            0.855369
# techanim - fur sim                         0.020933
# techanim - fur.sim                        -0.020933
# techanim - suit sim                        0.020933
# techanim - suit.sim                       -0.020933
# track - QC_Screens                        -0.020933
# track - camera_track_mp_v0001                   NaN
# track - char_single_frame_line_up          0.876302
# track - line_up_screens                    0.020933
# track - single_frame_line_up_Groot_Chair  -0.855369
# track - single_frame_line_up_Rocket_Chair -0.855369
# cost                                       1.000000
#
# [23 rows x 23 columns]
# df_all :
#          Julie Osborn  Kat Gore       cost
# abt1080             1         0  35.329167
# abt1160             1         0   2.125000
# abt1180             0         1  18.125000
#               Julie Osborn  Kat Gore      cost
# Julie Osborn      1.000000 -1.000000  0.020933
# Kat Gore         -1.000000  1.000000 -0.020933
# cost              0.020933 -0.020933  1.000000
# df_all :
#          fin  omt       cost
# abt1080    1    0  35.329167
# abt1160    0    1   2.125000
# abt1180    1    0  18.125000
#            fin       omt      cost
# fin   1.000000 -1.000000  0.855369
# omt  -1.000000  1.000000 -0.855369
# cost  0.855369 -0.855369  1.000000
# df_all :
#          abt       cost
# abt1080    1  35.329167
# abt1160    0   2.125000
# abt1180    1  18.125000
#            abt      cost
# abt   1.000000  0.855369
# cost  0.855369  1.000000
# df_all :
#          ABT1080  ABT1160  ABT1180       cost
# abt1080        1        0        0  35.329167
# abt1160        0        1        0   2.125000
# abt1180        0        0        1  18.125000
#           ABT1080   ABT1160   ABT1180      cost
# ABT1080  1.000000 -0.500000 -0.500000  0.876302
# ABT1160 -0.500000  1.000000 -0.500000 -0.855369
# ABT1180 -0.500000 -0.500000  1.000000 -0.020933
# cost     0.876302 -0.855369 -0.020933  1.000000
# df_all :
#          sg_ctd_percentage       cost
# abt1080                100  35.329167
# abt1160                 30   2.125000
# abt1180                100  18.125000
#                    sg_ctd_percentage      cost
# sg_ctd_percentage           1.000000  0.855369
# cost                        0.855369  1.000000
# df_all :
#          TO_003  TO_005       cost
# abt1080       1       0  35.329167
# abt1160       1       0   2.125000
# abt1180       0       1  18.125000
#           TO_003    TO_005      cost
# TO_003  1.000000 -1.000000  0.020933
# TO_005 -1.000000  1.000000 -0.020933
# cost    0.020933 -0.020933  1.000000
# df_all :
#          sg_cut_in       cost
# abt1080       1009  35.329167
# abt1160       1009   2.125000
# abt1180       1009  18.125000
#            sg_cut_in  cost
# sg_cut_in        NaN   NaN
# cost             NaN   1.0
# df_all :
#          sg_work_in       cost
# abt1080        1001  35.329167
# abt1160        1001   2.125000
# abt1180        1001  18.125000
#             sg_work_in  cost
# sg_work_in         NaN   NaN
# cost               NaN   1.0
# df_all :
#          AllSpice  AllSpice_keyshots  Brad ADR ref  Rocket  TO_003  TO_005  \
# abt1080         1                  1             1       1       1       0
# abt1160         1                  0             1       0       1       0
# abt1180         1                  0             1       1       0       1
#
#          Team_A  beat_1  keyshot       cost
# abt1080       1       1        1  35.329167
# abt1160       0       1        0   2.125000
# abt1180       1       1        0  18.125000
#                    AllSpice  AllSpice_keyshots  Brad ADR ref    Rocket  \
# AllSpice                NaN                NaN           NaN       NaN
# AllSpice_keyshots       NaN           1.000000           NaN  0.500000
# Brad ADR ref            NaN                NaN           NaN       NaN
# Rocket                  NaN           0.500000           NaN  1.000000
# TO_003                  NaN           0.500000           NaN -0.500000
# TO_005                  NaN          -0.500000           NaN  0.500000
# Team_A                  NaN           0.500000           NaN  1.000000
# beat_1                  NaN                NaN           NaN       NaN
# keyshot                 NaN           1.000000           NaN  0.500000
# cost                    NaN           0.876302           NaN  0.855369
#
#                      TO_003    TO_005    Team_A  beat_1   keyshot      cost
# AllSpice                NaN       NaN       NaN     NaN       NaN       NaN
# AllSpice_keyshots  0.500000 -0.500000  0.500000     NaN  1.000000  0.876302
# Brad ADR ref            NaN       NaN       NaN     NaN       NaN       NaN
# Rocket            -0.500000  0.500000  1.000000     NaN  0.500000  0.855369
# TO_003             1.000000 -1.000000 -0.500000     NaN  0.500000  0.020933
# TO_005            -1.000000  1.000000  0.500000     NaN -0.500000 -0.020933
# Team_A            -0.500000  0.500000  1.000000     NaN  0.500000  0.855369
# beat_1                  NaN       NaN       NaN     NaN       NaN       NaN
# keyshot            0.500000 -0.500000  0.500000     NaN  1.000000  0.876302
# cost               0.020933 -0.020933  0.855369     NaN  0.876302  1.000000
# df_all :
#          sg_cut_out       cost
# abt1080        1687  35.329167
# abt1160        1089   2.125000
# abt1180        1182  18.125000
#             sg_cut_out      cost
# sg_cut_out    1.000000  0.936722
# cost          0.936722  1.000000
# df_all :
#          Sc 35 Cam D  Sc 35D Cam D  Sc 35F Cam D       cost
# abt1080            1             0             0  35.329167
# abt1160            0             1             0   2.125000
# abt1180            0             0             1  18.125000
#               Sc 35 Cam D  Sc 35D Cam D  Sc 35F Cam D      cost
# Sc 35 Cam D      1.000000     -0.500000     -0.500000  0.876302
# Sc 35D Cam D    -0.500000      1.000000     -0.500000 -0.855369
# Sc 35F Cam D    -0.500000     -0.500000      1.000000 -0.020933
# cost             0.876302     -0.855369     -0.020933  1.000000
# df_all :
#          abt1080_plates_mp_v0001  abt1160_plates_mp_v0001  \
# abt1080                        1                        0
# abt1160                        0                        1
# abt1180                        0                        0
#
#          abt1180_plates_mp_v0001       cost
# abt1080                        0  35.329167
# abt1160                        0   2.125000
# abt1180                        1  18.125000
#                          abt1080_plates_mp_v0001  abt1160_plates_mp_v0001  \
# abt1080_plates_mp_v0001                 1.000000                -0.500000
# abt1160_plates_mp_v0001                -0.500000                 1.000000
# abt1180_plates_mp_v0001                -0.500000                -0.500000
# cost                                    0.876302                -0.855369
#
#                          abt1180_plates_mp_v0001      cost
# abt1080_plates_mp_v0001                -0.500000  0.876302
# abt1160_plates_mp_v0001                -0.500000 -0.855369
# abt1180_plates_mp_v0001                 1.000000 -0.020933
# cost                                   -0.020933  1.000000
# df_all :
#          sg_working_duration       cost
# abt1080                  695  35.329167
# abt1160                   97   2.125000
# abt1180                  190  18.125000
#                      sg_working_duration      cost
# sg_working_duration             1.000000  0.936722
# cost                            0.936722  1.000000
# df_all :
#          act  na       cost
# abt1080    0   1  35.329167
# abt1160    0   1   2.125000
# abt1180    1   0  18.125000
#            act        na      cost
# act   1.000000 -1.000000 -0.020933
# na   -1.000000  1.000000  0.020933
# cost -0.020933  0.020933  1.000000
# df_all :
#          antennae  benetar  cg  clean  color  comp  cosmetic  costume  drax  \
# abt1080         1        1   1      0      1     1         0        1     1
# abt1160         0        1   1      1      0     1         0        0     0
# abt1180         0        1   1      1      0     1         1        0     0
#
#          environment    ...      rocket  seatbelts  set  space  teen  up  \
# abt1080            1    ...           1          1    1      1     1   0
# abt1160            0    ...           1          1    1      0     1   1
# abt1180            0    ...           1          1    0      0     0   1
#
#          video  wig  windshield       cost
# abt1080      1    1           1  35.329167
# abt1160      1    0           1   2.125000
# abt1180      0    1           0  18.125000
#
# [3 rows x 40 columns]
#              antennae  benetar  cg     clean     color  comp  cosmetic  \
# antennae     1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# benetar           NaN      NaN NaN       NaN       NaN   NaN       NaN
# cg                NaN      NaN NaN       NaN       NaN   NaN       NaN
# clean       -1.000000      NaN NaN  1.000000 -1.000000   NaN  0.500000
# color        1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# comp              NaN      NaN NaN       NaN       NaN   NaN       NaN
# cosmetic    -0.500000      NaN NaN  0.500000 -0.500000   NaN  1.000000
# costume      1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# drax         1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# environment  1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# extension         NaN      NaN NaN       NaN       NaN   NaN       NaN
# eyelid       1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# eyes         1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# fix          0.500000      NaN NaN -0.500000  0.500000   NaN  0.500000
# fixes        1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# fx                NaN      NaN NaN       NaN       NaN   NaN       NaN
# game         0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# gamora       1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# glass        0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# graphics     1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# groot        0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# gs                NaN      NaN NaN       NaN       NaN   NaN       NaN
# handheld     0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# interactive       NaN      NaN NaN       NaN       NaN   NaN       NaN
# jump         1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# light             NaN      NaN NaN       NaN       NaN   NaN       NaN
# mantis       1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# paint       -1.000000      NaN NaN  1.000000 -1.000000   NaN  0.500000
# quill        0.500000      NaN NaN -0.500000  0.500000   NaN  0.500000
# raccoon      0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# rocket            NaN      NaN NaN       NaN       NaN   NaN       NaN
# seatbelts         NaN      NaN NaN       NaN       NaN   NaN       NaN
# set          0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# space        1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
# teen         0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# up          -1.000000      NaN NaN  1.000000 -1.000000   NaN  0.500000
# video        0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# wig          0.500000      NaN NaN -0.500000  0.500000   NaN  0.500000
# windshield   0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
# cost         0.876302      NaN NaN -0.876302  0.876302   NaN -0.020933
#
#               costume      drax  environment    ...     rocket  seatbelts  \
# antennae     1.000000  1.000000     1.000000    ...        NaN        NaN
# benetar           NaN       NaN          NaN    ...        NaN        NaN
# cg                NaN       NaN          NaN    ...        NaN        NaN
# clean       -1.000000 -1.000000    -1.000000    ...        NaN        NaN
# color        1.000000  1.000000     1.000000    ...        NaN        NaN
# comp              NaN       NaN          NaN    ...        NaN        NaN
# cosmetic    -0.500000 -0.500000    -0.500000    ...        NaN        NaN
# costume      1.000000  1.000000     1.000000    ...        NaN        NaN
# drax         1.000000  1.000000     1.000000    ...        NaN        NaN
# environment  1.000000  1.000000     1.000000    ...        NaN        NaN
# extension         NaN       NaN          NaN    ...        NaN        NaN
# eyelid       1.000000  1.000000     1.000000    ...        NaN        NaN
# eyes         1.000000  1.000000     1.000000    ...        NaN        NaN
# fix          0.500000  0.500000     0.500000    ...        NaN        NaN
# fixes        1.000000  1.000000     1.000000    ...        NaN        NaN
# fx                NaN       NaN          NaN    ...        NaN        NaN
# game         0.500000  0.500000     0.500000    ...        NaN        NaN
# gamora       1.000000  1.000000     1.000000    ...        NaN        NaN
# glass        0.500000  0.500000     0.500000    ...        NaN        NaN
# graphics     1.000000  1.000000     1.000000    ...        NaN        NaN
# groot        0.500000  0.500000     0.500000    ...        NaN        NaN
# gs                NaN       NaN          NaN    ...        NaN        NaN
# handheld     0.500000  0.500000     0.500000    ...        NaN        NaN
# interactive       NaN       NaN          NaN    ...        NaN        NaN
# jump         1.000000  1.000000     1.000000    ...        NaN        NaN
# ...
# abt1160         1097   2.125000
# abt1180         1190  18.125000
#              sg_work_out      cost
# sg_work_out     1.000000  0.936722
# cost            0.936722  1.000000
# df_all :
#          act       cost
# abt1080    1  35.329167
# abt1160    1   2.125000
# abt1180    1  18.125000
#       act  cost
# act   NaN   NaN
# cost  NaN   1.0
# df_all :
#          sg_client_version       cost
# abt1080                 19  35.329167
# abt1160                  1   2.125000
# abt1180                 21  18.125000
#                    sg_client_version      cost
# sg_client_version           1.000000  0.804809
# cost                        0.804809  1.000000
# df_all :
#          135mm (UP135-02)  50mm (UP50-01)       cost
# abt1080                 0               1  35.329167
# abt1160                 1               0   2.125000
# abt1180                 1               0  18.125000
#                   135mm (UP135-02)  50mm (UP50-01)      cost
# 135mm (UP135-02)          1.000000       -1.000000 -0.876302
# 50mm (UP50-01)           -1.000000        1.000000  0.876302
# cost                     -0.876302        0.876302  1.000000
# df_all :
#          Shot       cost
# abt1080     1  35.329167
# abt1160     1   2.125000
# abt1180     1  18.125000
#       Shot  cost
# Shot   NaN   NaN
# cost   NaN   1.0
# df_all :
#          2017-05-04  2017-08-02       cost
# abt1080           1           0  35.329167
# abt1160           1           0   2.125000
# abt1180           0           1  18.125000
#             2017-05-04  2017-08-02      cost
# 2017-05-04    1.000000   -1.000000  0.020933
# 2017-08-02   -1.000000    1.000000 -0.020933
# cost          0.020933   -0.020933  1.000000
# df_all :
#          adolescent  and  are  because  blank  but  cheddar  cheese  doing  \
# abt1080           1    1    0        0      0    0        0       0      0
# abt1160           0    0    1        0      1    1        0       0      1
# abt1180           0    1    1        1      0    1        1       1      1
#
#          drax    ...      that  their  uh  us  video  we  whoever  why  will  \
# abt1080     1    ...         0      1   0   0      1   0        0    0     0
# abt1160     0    ...         1      0   1   0      0   1        0    1     0
# abt1180     0    ...         1      0   0   1      0   1        1    1     1
#
#               cost
# abt1080  35.329167
# abt1160   2.125000
# abt1180  18.125000
#
# [3 rows x 45 columns]
#             adolescent       and       are   because     blank       but  \
# adolescent    1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# and           0.500000  1.000000 -0.500000  0.500000 -1.000000 -0.500000
# are          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# because      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# blank        -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
# but          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# cheddar      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# cheese       -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# doing        -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# drax          1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# efforts      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# flight        1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# for          -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# game          1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# gamora        1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# get          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# give         -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# groot         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# handheld      1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# huh          -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
# in            1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# is           -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# it           -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# little       -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# mantis        1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# maybe        -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# nice         -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# our          -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# plays         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# quill         0.500000  1.000000 -0.500000  0.500000 -1.000000 -0.500000
# re           -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# rocket             NaN       NaN       NaN       NaN       NaN       NaN
# seats         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# sit           1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# stares       -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
# that         -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# their         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# uh           -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
# us           -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# video         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
# we           -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# whoever      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# why          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
# will         -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
# cost          0.876302  0.855369 -0.876302 -0.020933 -0.855369 -0.876302
#
#              cheddar    cheese     doing      drax    ...         that  \
# adolescent -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# and         0.500000  0.500000 -0.500000  0.500000    ...    -0.500000
# are         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# because     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# blank      -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
# but         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# cheddar     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# cheese      1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# doing       0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# drax       -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# efforts     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# flight     -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# for         1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# game       -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# gamora     -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# get         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# give        1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# groot      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# handheld   -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# huh        -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
# in         -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# is          1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# it          0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# little      1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# mantis     -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# maybe       1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# nice        1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# our         1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# plays      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# quill       0.500000  0.500000 -0.500000  0.500000    ...    -0.500000
# re          1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# rocket           NaN       NaN       NaN       NaN    ...          NaN
# seats      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# sit        -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# stares     -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
# that        0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# their      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# uh         -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
# us          1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# video      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
# we          0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# whoever     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# why         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
# will        1.000000  1.000000  0.500000 -0.500000    ...     0.500000
# cost       -0.020933 -0.020933 -0.876302  0.876302    ...    -0.876302
#
#                their        uh        us     video        we   whoever  \
# adolescent  1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# and         0.500000 -1.000000  0.500000  0.500000 -0.500000  0.500000
# are        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# because    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# blank      -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
# but        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# cheddar    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# cheese     -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# doing      -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# drax        1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# efforts    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# flight      1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# for        -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# game        1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# gamora      1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# get        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# give       -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# groot       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# handheld    1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# huh        -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
# in          1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# is         -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# it         -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# little     -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# mantis      1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# maybe      -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# nice       -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# our        -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# plays       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# quill       0.500000 -1.000000  0.500000  0.500000 -0.500000  0.500000
# re         -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# rocket           NaN       NaN       NaN       NaN       NaN       NaN
# seats       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# sit         1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# stares     -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
# that       -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# their       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# uh         -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
# us         -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# video       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
# we         -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# whoever    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# why        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
# will       -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
# cost        0.876302 -0.855369 -0.020933  0.876302 -0.876302 -0.020933
#
#                  why      will      cost
# adolescent -1.000000 -0.500000  0.876302
# and        -0.500000  0.500000  0.855369
# are         1.000000  0.500000 -0.876302
# because     0.500000  1.000000 -0.020933
# blank       0.500000 -0.500000 -0.855369
# but         1.000000  0.500000 -0.876302
# cheddar     0.500000  1.000000 -0.020933
# cheese      0.500000  1.000000 -0.020933
# doing       1.000000  0.500000 -0.876302
# drax       -1.000000 -0.500000  0.876302
# efforts     0.500000  1.000000 -0.020933
# flight     -1.000000 -0.500000  0.876302
# for         0.500000  1.000000 -0.020933
# game       -1.000000 -0.500000  0.876302
# gamora     -1.000000 -0.500000  0.876302
# get         1.000000  0.500000 -0.876302
# give        0.500000  1.000000 -0.020933
# groot      -1.000000 -0.500000  0.876302
# handheld   -1.000000 -0.500000  0.876302
# huh         0.500000 -0.500000 -0.855369
# in         -1.000000 -0.500000  0.876302
# is          0.500000  1.000000 -0.020933
# it          1.000000  0.500000 -0.876302
# little      0.500000  1.000000 -0.020933
# mantis     -1.000000 -0.500000  0.876302
# maybe       0.500000  1.000000 -0.020933
# nice        0.500000  1.000000 -0.020933
# our         0.500000  1.000000 -0.020933
# plays      -1.000000 -0.500000  0.876302
# quill      -0.500000  0.500000  0.855369
# re          0.500000  1.000000 -0.020933
# rocket           NaN       NaN       NaN
# seats      -1.000000 -0.500000  0.876302
# sit        -1.000000 -0.500000  0.876302
# stares      0.500000 -0.500000 -0.855369
# that        1.000000  0.500000 -0.876302
# their      -1.000000 -0.500000  0.876302
# uh          0.500000 -0.500000 -0.855369
# us          0.500000  1.000000 -0.020933
# video      -1.000000 -0.500000  0.876302
# we          1.000000  0.500000 -0.876302
# whoever     0.500000  1.000000 -0.020933
# why         1.000000  0.500000 -0.876302
# will        0.500000  1.000000 -0.020933
# cost       -0.876302 -0.020933  1.000000
#
# [45 rows x 45 columns]
# df_all :
#         sg_good_for_temp       cost
# abt1080                0  35.329167
# abt1160                0   2.125000
# abt1180             True  18.125000
#       cost
# cost   1.0
# df_all :
#          Mary Lou       cost
# abt1080         1  35.329167
# abt1160         1   2.125000
# abt1180         1  18.125000
#           Mary Lou  cost
# Mary Lou       NaN   NaN
# cost           NaN   1.0
# df_all :
#          2       cost
# abt1080  1  35.329167
# abt1160  0   2.125000
# abt1180  1  18.125000
#              2      cost
# 2     1.000000  0.855369
# cost  0.855369  1.000000
# df_all :
#          Mark Derksen       cost
# abt1080             0  35.329167
# abt1160             0   2.125000
# abt1180             1  18.125000
#               Mark Derksen      cost
# Mark Derksen      1.000000 -0.020933
# cost             -0.020933  1.000000
# df_all :
#          sg_tail_handle       cost
# abt1080               8  35.329167
# abt1160               8   2.125000
# abt1180               8  18.125000
#                 sg_tail_handle  cost
# sg_tail_handle             NaN   NaN
# cost                       NaN   1.0
# df_all :
#          Los Angeles       cost
# abt1080            1  35.329167
# abt1160            1   2.125000
# abt1180            1  18.125000
#              Los Angeles  cost
# Los Angeles          NaN   NaN
# cost                 NaN   1.0
# df_complete :

# %%
fig,axn = plt.subplots(len(heatmap), 1, figsize=(15,500))

count = 0
for ax in axn.flat: 
    sns.heatmap(heatmap[count], ax=ax)
    count += 1

# %%
df_complete
# Out:
#          open_notes_count  abt1080  abt1160  abt1180  2018-03-09  2018-03-16  \
# abt1080               377        1        0        0           0           1
# abt1160                16        0        1        0           0           0
# abt1180               110        0        0        1           1           0
#
#          TEAM A  sg_shot_length  sg_cut_order  apr    ...      whoever  why  \
# abt1080       1             695             4    1    ...            0    0
# abt1160       0              97             0    0    ...            0    1
# abt1180       1             190             6    1    ...            1    1
#
#          will  sg_good_for_temp  Mary Lou  2  Mark Derksen  sg_tail_handle  \
# abt1080     0                 0         1  1             0               8
# abt1160     0                 0         1  0             0               8
# abt1180     1              True         1  1             1               8
#
#          Los Angeles       cost
# abt1080            1  35.329167
# abt1160            1   2.125000
# abt1180            1  18.125000
#
# [3 rows x 179 columns]

# %%
shotgun_source_generator.heatmap
# Out:
# [('open_notes_count',          open_notes_count       cost
#   abt1080               377  35.329167
#   abt1160                16   2.125000
#   abt1180               110  18.125000,                   open_notes_count      cost
#   open_notes_count          1.000000  0.969161
#   cost                      0.969161  1.000000),
#  ('code',          abt1080  abt1160  abt1180       cost
#   abt1080        1        0        0  35.329167
#   abt1160        0        1        0   2.125000
#   abt1180        0        0        1  18.125000,           abt1080   abt1160   abt1180      cost
#   abt1080  1.000000 -0.500000 -0.500000  0.876302
#   abt1160 -0.500000  1.000000 -0.500000 -0.855369
#   abt1180 -0.500000 -0.500000  1.000000 -0.020933
#   cost     0.876302 -0.855369 -0.020933  1.000000),
#  ('sg_final_due_date',          2018-03-09  2018-03-16       cost
#   abt1080           0           1  35.329167
#   abt1160           0           0   2.125000
#   abt1180           1           0  18.125000,             2018-03-09  2018-03-16      cost
#   2018-03-09    1.000000   -0.500000 -0.020933
#   2018-03-16   -0.500000    1.000000  0.876302
#   cost         -0.020933    0.876302  1.000000),
#  ('sg_assumptions',          TEAM A       cost
#   abt1080       1  35.329167
#   abt1160       0   2.125000
#   abt1180       1  18.125000,           TEAM A      cost
#   TEAM A  1.000000  0.855369
#   cost    0.855369  1.000000),
#  ('sg_shot_length',          sg_shot_length       cost
#   abt1080             695  35.329167
#   abt1160              97   2.125000
#   abt1180             190  18.125000,                 sg_shot_length      cost
#   sg_shot_length        1.000000  0.936722
#   cost                  0.936722  1.000000),
#  ('sg_cut_order',          sg_cut_order       cost
#   abt1080             4  35.329167
#   abt1160             0   2.125000
#   abt1180             6  18.125000,               sg_cut_order      cost
#   sg_cut_order      1.000000  0.638686
#   cost              0.638686  1.000000),
#  ('sg_status_stereo',          apr  na       cost
#   abt1080    1   0  35.329167
#   abt1160    0   1   2.125000
#   abt1180    1   0  18.125000,            apr        na      cost
#   apr   1.000000 -1.000000  0.855369
#   na   -1.000000  1.000000 -0.855369
#   cost  0.855369 -0.855369  1.000000),
#  ('sg_cut_duration',          sg_cut_duration       cost
#   abt1080              679  35.329167
#   abt1160               81   2.125000
#   abt1180              174  18.125000,                  sg_cut_duration      cost
#   sg_cut_duration         1.000000  0.936722
#   cost                    0.936722  1.000000),
#  ('cached_display_name',          abt1080  abt1160  abt1180       cost
#   abt1080        1        0        0  35.329167
#   abt1160        0        1        0   2.125000
#   abt1180        0        0        1  18.125000,           abt1080   abt1160   abt1180      cost
#   abt1080  1.000000 -0.500000 -0.500000  0.876302
#   abt1160 -0.500000  1.000000 -0.500000 -0.855369
#   abt1180 -0.500000 -0.500000  1.000000 -0.020933
#   cost     0.876302 -0.855369 -0.020933  1.000000),
#  ('id',             id       cost
#   abt1080  33183  35.329167
#   abt1160  33185   2.125000
#   abt1180  37238  18.125000,            id     cost
#   id    1.00000 -0.02136
#   cost -0.02136  1.00000),
#  ('updated_by',          Julie Osborn  Tom Luna       cost
#   abt1080             0         1  35.329167
#   abt1160             1         0   2.125000
#   abt1180             0         1  18.125000,               Julie Osborn  Tom Luna      cost
#   Julie Osborn      1.000000 -1.000000 -0.855369
#   Tom Luna         -1.000000  1.000000  0.855369
#   cost             -0.855369  0.855369  1.000000),
#  ('sg_head_handle',          sg_head_handle       cost
#   abt1080               8  35.329167
#   abt1160               8   2.125000
#   abt1180               8  18.125000,                 sg_head_handle  cost
#   sg_head_handle             NaN   NaN
#   cost                       NaN   1.0),
#  ('tasks',          anim - anim  comp - cgfg  comp - comp  dmp - window dmp  \
#   abt1080            1            1            1                 1
#   abt1160            0            0            1                 0
#   abt1180            1            0            1                 1
#
#            fx - jumpspace  layout - layout_assembly  light - light  \
#   abt1080               1                         1              1
#   abt1160               0                         1              1
#   abt1180               0                         1              1
#
#            matchmove - 100%_char_Mantis_head  paint - paint  roto - roto  \
#   abt1080                                  1              1            1
#   abt1160                                  0              1            1
#   abt1180                                  0              1            1
#
#              ...      techanim - fur.sim  techanim - suit sim  \
#   abt1080    ...                       0                    1
#   abt1160    ...                       0                    1
#   abt1180    ...                       1                    0
#
#            techanim - suit.sim  track - QC_Screens  \
#   abt1080                    0                   0
#   abt1160                    0                   0
#   abt1180                    1                   1
#
#            track - camera_track_mp_v0001  track - char_single_frame_line_up  \
#   abt1080                              1                                  1
#   abt1160                              1                                  0
#   abt1180                              1                                  0
#
#            track - line_up_screens  track - single_frame_line_up_Groot_Chair  \
#   abt1080                        1                                         0
#   abt1160                        1                                         1
#   abt1180                        0                                         0
#
#            track - single_frame_line_up_Rocket_Chair       cost
#   abt1080                                          0  35.329167
#   abt1160                                          1   2.125000
#   abt1180                                          0  18.125000
#
#   [3 rows x 23 columns],                                            anim - anim  comp - cgfg  \
#   anim - anim                                   1.000000     0.500000
#   comp - cgfg                                   0.500000     1.000000
#   comp - comp                                        NaN          NaN
#   dmp - window dmp                              1.000000     0.500000
#   fx - jumpspace                                0.500000     1.000000
#   layout - layout_assembly                           NaN          NaN
#   light - light                                      NaN          NaN
#   matchmove - 100%_char_Mantis_head             0.500000     1.000000
#   paint - paint                                      NaN          NaN
#   roto - roto                                        NaN          NaN
#   roto - roto rocket                            0.500000     1.000000
#   stereo - stereo                               1.000000     0.500000
#   techanim - fur sim                           -0.500000     0.500000
#   techanim - fur.sim                            0.500000    -0.500000
#   techanim - suit sim                          -0.500000     0.500000
#   techanim - suit.sim                           0.500000    -0.500000
#   track - QC_Screens                            0.500000    -0.500000
#   track - camera_track_mp_v0001                      NaN          NaN
#   track - char_single_frame_line_up             0.500000     1.000000
#   track - line_up_screens                      -0.500000     0.500000
#   track - single_frame_line_up_Groot_Chair     -1.000000    -0.500000
#   track - single_frame_line_up_Rocket_Chair    -1.000000    -0.500000
#   cost                                          0.855369     0.876302
#
#                                              comp - comp  dmp - window dmp  \
#   anim - anim                                        NaN          1.000000
#   comp - cgfg                                        NaN          0.500000
#   comp - comp                                        NaN               NaN
#   dmp - window dmp                                   NaN          1.000000
#   fx - jumpspace                                     NaN          0.500000
#   layout - layout_assembly                           NaN               NaN
#   light - light                                      NaN               NaN
#   matchmove - 100%_char_Mantis_head                  NaN          0.500000
#   paint - paint                                      NaN               NaN
#   roto - roto                                        NaN               NaN
#   roto - roto rocket                                 NaN          0.500000
#   stereo - stereo                                    NaN          1.000000
#   techanim - fur sim                                 NaN         -0.500000
#   techanim - fur.sim                                 NaN          0.500000
#   techanim - suit sim                                NaN         -0.500000
#   techanim - suit.sim                                NaN          0.500000
#   track - QC_Screens                                 NaN          0.500000
#   track - camera_track_mp_v0001                      NaN               NaN
#   track - char_single_frame_line_up                  NaN          0.500000
#   track - line_up_screens                            NaN         -0.500000
#   track - single_frame_line_up_Groot_Chair           NaN         -1.000000
#   track - single_frame_line_up_Rocket_Chair          NaN         -1.000000
#   cost                                               NaN          0.855369
#
#                                              fx - jumpspace  \
#   anim - anim                                      0.500000
#   comp - cgfg                                      1.000000
#   comp - comp                                           NaN
#   dmp - window dmp                                 0.500000
#   fx - jumpspace                                   1.000000
#   layout - layout_assembly                              NaN
#   light - light                                         NaN
#   matchmove - 100%_char_Mantis_head                1.000000
#   paint - paint                                         NaN
#   roto - roto                                           NaN
#   roto - roto rocket                               1.000000
#   stereo - stereo                                  0.500000
#   techanim - fur sim                               0.500000
#   techanim - fur.sim                              -0.500000
#   techanim - suit sim                              0.500000
#   techanim - suit.sim                             -0.500000
#   track - QC_Screens                              -0.500000
#   track - camera_track_mp_v0001                         NaN
#   track - char_single_frame_line_up                1.000000
#   track - line_up_screens                          0.500000
#   track - single_frame_line_up_Groot_Chair        -0.500000
#   track - single_frame_line_up_Rocket_Chair       -0.500000
#   cost                                             0.876302
#
#                                              layout - layout_assembly  \
#   anim - anim                                                     NaN
#   comp - cgfg                                                     NaN
#   comp - comp                                                     NaN
#   dmp - window dmp                                                NaN
#   fx - jumpspace                                                  NaN
#   layout - layout_assembly                                        NaN
#   light - light                                                   NaN
#   matchmove - 100%_char_Mantis_head                               NaN
#   paint - paint                                                   NaN
#   roto - roto                                                     NaN
#   roto - roto rocket                                              NaN
#   stereo - stereo                                                 NaN
#   techanim - fur sim                                              NaN
#   techanim - fur.sim                                              NaN
#   techanim - suit sim                                             NaN
#   techanim - suit.sim                                             NaN
#   track - QC_Screens                                              NaN
#   track - camera_track_mp_v0001                                   NaN
#   track - char_single_frame_line_up                               NaN
#   track - line_up_screens                                         NaN
#   track - single_frame_line_up_Groot_Chair                        NaN
#   track - single_frame_line_up_Rocket_Chair                       NaN
#   cost                                                            NaN
#
#                                              light - light  \
#   anim - anim                                          NaN
#   comp - cgfg                                          NaN
#   comp - comp                                          NaN
#   dmp - window dmp                                     NaN
#   fx - jumpspace                                       NaN
#   layout - layout_assembly                             NaN
#   light - light                                        NaN
#   matchmove - 100%_char_Mantis_head                    NaN
#   paint - paint                                        NaN
#   roto - roto                                          NaN
#   roto - roto rocket                                   NaN
#   stereo - stereo                                      NaN
#   techanim - fur sim                                   NaN
#   techanim - fur.sim                                   NaN
#   techanim - suit sim                                  NaN
#   techanim - suit.sim                                  NaN
#   track - QC_Screens                                   NaN
#   track - camera_track_mp_v0001                        NaN
#   track - char_single_frame_line_up                    NaN
#   track - line_up_screens                              NaN
#   track - single_frame_line_up_Groot_Chair             NaN
#   track - single_frame_line_up_Rocket_Chair            NaN
#   cost                                                 NaN
#
#                                              matchmove - 100%_char_Mantis_head  \
#   anim - anim                                                         0.500000
#   comp - cgfg                                                         1.000000
#   comp - comp                                                              NaN
#   dmp - window dmp                                                    0.500000
#   fx - jumpspace                                                      1.000000
#   layout - layout_assembly                                                 NaN
#   light - light                                                            NaN
#   matchmove - 100%_char_Mantis_head                                   1.000000
#   paint - paint                                                            NaN
#   roto - roto                                                              NaN
#   roto - roto rocket                                                  1.000000
#   stereo - stereo                                                     0.500000
#   techanim - fur sim                                                  0.500000
#   techanim - fur.sim                                                 -0.500000
#   techanim - suit sim                                                 0.500000
#   techanim - suit.sim                                                -0.500000
#   track - QC_Screens                                                 -0.500000
#   track - camera_track_mp_v0001                                            NaN
#   track - char_single_frame_line_up                                   1.000000
#   track - line_up_screens                                             0.500000
#   track - single_frame_line_up_Groot_Chair                           -0.500000
#   track - single_frame_line_up_Rocket_Chair                          -0.500000
#   cost                                                                0.876302
#
#                                              paint - paint  roto - roto  \
#   anim - anim                                          NaN          NaN
#   comp - cgfg                                          NaN          NaN
#   comp - comp                                          NaN          NaN
#   dmp - window dmp                                     NaN          NaN
#   fx - jumpspace                                       NaN          NaN
#   layout - layout_assembly                             NaN          NaN
#   light - light                                        NaN          NaN
#   matchmove - 100%_char_Mantis_head                    NaN          NaN
#   paint - paint                                        NaN          NaN
#   roto - roto                                          NaN          NaN
#   roto - roto rocket                                   NaN          NaN
#   stereo - stereo                                      NaN          NaN
#   techanim - fur sim                                   NaN          NaN
#   techanim - fur.sim                                   NaN          NaN
#   techanim - suit sim                                  NaN          NaN
#   techanim - suit.sim                                  NaN          NaN
#   track - QC_Screens                                   NaN          NaN
#   track - camera_track_mp_v0001                        NaN          NaN
#   track - char_single_frame_line_up                    NaN          NaN
#   track - line_up_screens                              NaN          NaN
#   track - single_frame_line_up_Groot_Chair             NaN          NaN
#   track - single_frame_line_up_Rocket_Chair            NaN          NaN
#   cost                                                 NaN          NaN
#
#                                                ...     techanim - fur.sim  \
#   anim - anim                                  ...               0.500000
#   comp - cgfg                                  ...              -0.500000
#   comp - comp                                  ...                    NaN
#   dmp - window dmp                             ...               0.500000
#   fx - jumpspace                               ...              -0.500000
#   layout - layout_assembly                     ...                    NaN
#   light - light                                ...                    NaN
#   matchmove - 100%_char_Mantis_head            ...              -0.500000
#   paint - paint                                ...                    NaN
#   roto - roto                                  ...                    NaN
#   roto - roto rocket                           ...              -0.500000
#   stereo - stereo                              ...               0.500000
#   techanim - fur sim                           ...              -1.000000
#   techanim - fur.sim                           ...               1.000000
#   techanim - suit sim                          ...              -1.000000
#   techanim - suit.sim                          ...               1.000000
#   track - QC_Screens                           ...               1.000000
#   track - camera_track_mp_v0001                ...                    NaN
#   track - char_single_frame_line_up            ...              -0.500000
#   track - line_up_screens                      ...              -1.000000
#   track - single_frame_line_up_Groot_Chair     ...              -0.500000
#   track - single_frame_line_up_Rocket_Chair    ...              -0.500000
#   cost                                         ...              -0.020933
#
#                                              techanim - suit sim  \
#   anim - anim                                          -0.500000
#   comp - cgfg                                           0.500000
#   comp - comp                                                NaN
#   dmp - window dmp                                     -0.500000
#   fx - jumpspace                                        0.500000
#   layout - layout_assembly                                   NaN
#   light - light                                              NaN
#   matchmove - 100%_char_Mantis_head                     0.500000
#   paint - paint                                              NaN
#   roto - roto                                                NaN
#   roto - roto rocket                                    0.500000
#   stereo - stereo                                      -0.500000
#   techanim - fur sim                                    1.000000
#   techanim - fur.sim                                   -1.000000
#   techanim - suit sim                                   1.000000
#   techanim - suit.sim                                  -1.000000
#   track - QC_Screens                                   -1.000000
#   track - camera_track_mp_v0001                              NaN
#   track - char_single_frame_line_up                     0.500000
#   track - line_up_screens                               1.000000
#   track - single_frame_line_up_Groot_Chair              0.500000
#   track - single_frame_line_up_Rocket_Chair             0.500000
#   cost                                                  0.020933
#
#                                              techanim - suit.sim  \
#   anim - anim                                           0.500000
#   comp - cgfg                                          -0.500000
#   comp - comp                                                NaN
#   dmp - window dmp                                      0.500000
#   fx - jumpspace                                       -0.500000
#   layout - layout_assembly                                   NaN
#   light - light                                              NaN
#   matchmove - 100%_char_Mantis_head                    -0.500000
#   paint - paint                                              NaN
#   roto - roto                                                NaN
#   roto - roto rocket                                   -0.500000
#   stereo - stereo                                       0.500000
#   techanim - fur sim                                   -1.000000
#   techanim - fur.sim                                    1.000000
#   techanim - suit sim                                  -1.000000
#   techanim - suit.sim                                   1.000000
#   track - QC_Screens                                    1.000000
#   track - camera_track_mp_v0001                              NaN
#   track - char_single_frame_line_up                    -0.500000
#   track - line_up_screens                              -1.000000
#   track - single_frame_line_up_Groot_Chair             -0.500000
#   track - single_frame_line_up_Rocket_Chair            -0.500000
#   cost                                                 -0.020933
#
#                                              track - QC_Screens  \
#   anim - anim                                          0.500000
#   comp - cgfg                                         -0.500000
#   comp - comp                                               NaN
#   dmp - window dmp                                     0.500000
#   fx - jumpspace                                      -0.500000
#   layout - layout_assembly                                  NaN
#   light - light                                             NaN
#   matchmove - 100%_char_Mantis_head                   -0.500000
#   paint - paint                                             NaN
#   roto - roto                                               NaN
#   roto - roto rocket                                  -0.500000
#   stereo - stereo                                      0.500000
#   techanim - fur sim                                  -1.000000
#   techanim - fur.sim                                   1.000000
#   techanim - suit sim                                 -1.000000
#   techanim - suit.sim                                  1.000000
#   track - QC_Screens                                   1.000000
#   track - camera_track_mp_v0001                             NaN
#   track - char_single_frame_line_up                   -0.500000
#   track - line_up_screens                             -1.000000
#   track - single_frame_line_up_Groot_Chair            -0.500000
#   track - single_frame_line_up_Rocket_Chair           -0.500000
#   cost                                                -0.020933
#
#                                              track - camera_track_mp_v0001  \
#   anim - anim                                                          NaN
#   comp - cgfg                                                          NaN
#   comp - comp                                                          NaN
#   dmp - window dmp                                                     NaN
#   fx - jumpspace                                                       NaN
#   layout - layout_assembly                                             NaN
#   light - light                                                        NaN
#   matchmove - 100%_char_Mantis_head                                    NaN
#   paint - paint                                                        NaN
#   roto - roto                                                          NaN
#   roto - roto rocket                                                   NaN
#   stereo - stereo                                                      NaN
#   techanim - fur sim                                                   NaN
#   techanim - fur.sim                                                   NaN
#   techanim - suit sim                                                  NaN
#   techanim - suit.sim                                                  NaN
#   track - QC_Screens                                                   NaN
#   track - camera_track_mp_v0001                                        NaN
#   track - char_single_frame_line_up                                    NaN
#   track - line_up_screens                                              NaN
#   track - single_frame_line_up_Groot_Chair                             NaN
#   track - single_frame_line_up_Rocket_Chair                            NaN
#   cost                                                                 NaN
#
#                                              track - char_single_frame_line_up  \
#   anim - anim                                                         0.500000
#   comp - cgfg                                                         1.000000
#   comp - comp                                                              NaN
#   dmp - window dmp                                                    0.500000
#   fx - jumpspace                                                      1.000000
#   layout - layout_assembly                                                 NaN
#   light - light                                                            NaN
#   matchmove - 100%_char_Mantis_head                                   1.000000
#   paint - paint                                                            NaN
#   roto - roto                                                              NaN
#   roto - roto rocket                                                  1.000000
#   stereo - stereo                                                     0.500000
#   techanim - fur sim                                                  0.500000
#   techanim - fur.sim                                                 -0.500000
#   techanim - suit sim                                                 0.500000
#   techanim - suit.sim                                                -0.500000
#   track - QC_Screens                                                 -0.500000
#   track - camera_track_mp_v0001                                            NaN
#   track - char_single_frame_line_up                                   1.000000
#   track - line_up_screens                                             0.500000
#   track - single_frame_line_up_Groot_Chair                           -0.500000
#   track - single_frame_line_up_Rocket_Chair                          -0.500000
#   cost                                                                0.876302
#
#                                              track - line_up_screens  \
#   anim - anim                                              -0.500000
#   comp - cgfg                                               0.500000
#   comp - comp                                                    NaN
#   dmp - window dmp                                         -0.500000
#   fx - jumpspace                                            0.500000
#   layout - layout_assembly                                       NaN
#   light - light                                                  NaN
#   matchmove - 100%_char_Mantis_head                         0.500000
#   paint - paint                                                  NaN
#   roto - roto                                                    NaN
#   roto - roto rocket                                        0.500000
#   stereo - stereo                                          -0.500000
#   techanim - fur sim                                        1.000000
#   techanim - fur.sim                                       -1.000000
#   techanim - suit sim                                       1.000000
#   techanim - suit.sim                                      -1.000000
#   track - QC_Screens                                       -1.000000
#   track - camera_track_mp_v0001                                  NaN
#   track - char_single_frame_line_up                         0.500000
#   track - line_up_screens                                   1.000000
#   track - single_frame_line_up_Groot_Chair                  0.500000
#   track - single_frame_line_up_Rocket_Chair                 0.500000
#   cost                                                      0.020933
#
#                                              track - single_frame_line_up_Groot_Chair  \
#   anim - anim                                                               -1.000000
#   comp - cgfg                                                               -0.500000
#   comp - comp                                                                     NaN
#   dmp - window dmp                                                          -1.000000
#   fx - jumpspace                                                            -0.500000
#   layout - layout_assembly                                                        NaN
#   light - light                                                                   NaN
#   matchmove - 100%_char_Mantis_head                                         -0.500000
#   paint - paint                                                                   NaN
#   roto - roto                                                                     NaN
#   roto - roto rocket                                                        -0.500000
#   stereo - stereo                                                           -1.000000
#   techanim - fur sim                                                         0.500000
#   techanim - fur.sim                                                        -0.500000
#   techanim - suit sim                                                        0.500000
#   techanim - suit.sim                                                       -0.500000
#   track - QC_Screens                                                        -0.500000
#   track - camera_track_mp_v0001                                                   NaN
#   track - char_single_frame_line_up                                         -0.500000
#   track - line_up_screens                                                    0.500000
#   track - single_frame_line_up_Groot_Chair                                   1.000000
#   track - single_frame_line_up_Rocket_Chair                                  1.000000
#   cost                                                                      -0.855369
#
#                                              track - single_frame_line_up_Rocket_Chair  \
#   anim - anim                                                                -1.000000
#   comp - cgfg                                                                -0.500000
#   comp - comp                                                                      NaN
#   dmp - window dmp                                                           -1.000000
#   fx - jumpspace                                                             -0.500000
#   layout - layout_assembly                                                         NaN
#   light - light                                                                    NaN
#   matchmove - 100%_char_Mantis_head                                          -0.500000
#   paint - paint                                                                    NaN
#   roto - roto                                                                      NaN
#   roto - roto rocket                                                         -0.500000
#   stereo - stereo                                                            -1.000000
#   techanim - fur sim                                                          0.500000
#   techanim - fur.sim                                                         -0.500000
#   techanim - suit sim                                                         0.500000
#   techanim - suit.sim                                                        -0.500000
#   track - QC_Screens                                                         -0.500000
#   track - camera_track_mp_v0001                                                    NaN
#   track - char_single_frame_line_up                                          -0.500000
#   track - line_up_screens                                                     0.500000
#   track - single_frame_line_up_Groot_Chair                                    1.000000
#   track - single_frame_line_up_Rocket_Chair                                   1.000000
#   cost                                                                       -0.855369
#
#                                                  cost
#   anim - anim                                0.855369
#   comp - cgfg                                0.876302
#   comp - comp                                     NaN
#   dmp - window dmp                           0.855369
#   fx - jumpspace                             0.876302
#   layout - layout_assembly                        NaN
#   light - light                                   NaN
#   matchmove - 100%_char_Mantis_head          0.876302
#   paint - paint                                   NaN
#   roto - roto                                     NaN
#   roto - roto rocket                         0.876302
#   stereo - stereo                            0.855369
#   techanim - fur sim                         0.020933
#   techanim - fur.sim                        -0.020933
#   techanim - suit sim                        0.020933
#   techanim - suit.sim                       -0.020933
#   track - QC_Screens                        -0.020933
#   track - camera_track_mp_v0001                   NaN
#   track - char_single_frame_line_up          0.876302
#   track - line_up_screens                    0.020933
#   track - single_frame_line_up_Groot_Chair  -0.855369
#   track - single_frame_line_up_Rocket_Chair -0.855369
#   cost                                       1.000000
#
#   [23 rows x 23 columns]),
#  ('created_by',          Julie Osborn  Kat Gore       cost
#   abt1080             1         0  35.329167
#   abt1160             1         0   2.125000
#   abt1180             0         1  18.125000,               Julie Osborn  Kat Gore      cost
#   Julie Osborn      1.000000 -1.000000  0.020933
#   Kat Gore         -1.000000  1.000000 -0.020933
#   cost              0.020933 -0.020933  1.000000),
#  ('sg_status_list',          fin  omt       cost
#   abt1080    1    0  35.329167
#   abt1160    0    1   2.125000
#   abt1180    1    0  18.125000,            fin       omt      cost
#   fin   1.000000 -1.000000  0.855369
#   omt  -1.000000  1.000000 -0.855369
#   cost  0.855369 -0.855369  1.000000),
#  ('sg_sequence',          abt       cost
#   abt1080    1  35.329167
#   abt1160    0   2.125000
#   abt1180    1  18.125000,            abt      cost
#   abt   1.000000  0.855369
#   cost  0.855369  1.000000),
#  ('sg_client_name',          ABT1080  ABT1160  ABT1180       cost
#   abt1080        1        0        0  35.329167
#   abt1160        0        1        0   2.125000
#   abt1180        0        0        1  18.125000,           ABT1080   ABT1160   ABT1180      cost
#   ABT1080  1.000000 -0.500000 -0.500000  0.876302
#   ABT1160 -0.500000  1.000000 -0.500000 -0.855369
#   ABT1180 -0.500000 -0.500000  1.000000 -0.020933
#   cost     0.876302 -0.855369 -0.020933  1.000000),
#  ('sg_ctd_percentage',          sg_ctd_percentage       cost
#   abt1080                100  35.329167
#   abt1160                 30   2.125000
#   abt1180                100  18.125000,                    sg_ctd_percentage      cost
#   sg_ctd_percentage           1.000000  0.855369
#   cost                        0.855369  1.000000),
#  ('sg_turnover',          TO_003  TO_005       cost
#   abt1080       1       0  35.329167
#   abt1160       1       0   2.125000
#   abt1180       0       1  18.125000,           TO_003    TO_005      cost
#   TO_003  1.000000 -1.000000  0.020933
#   TO_005 -1.000000  1.000000 -0.020933
#   cost    0.020933 -0.020933  1.000000),
#  ('sg_cut_in',          sg_cut_in       cost
#   abt1080       1009  35.329167
#   abt1160       1009   2.125000
#   abt1180       1009  18.125000,            sg_cut_in  cost
#   sg_cut_in        NaN   NaN
#   cost             NaN   1.0),
#  ('sg_work_in',          sg_work_in       cost
#   abt1080        1001  35.329167
#   abt1160        1001   2.125000
#   abt1180        1001  18.125000,             sg_work_in  cost
#   sg_work_in         NaN   NaN
#   cost               NaN   1.0),
#  ('tags',
#            AllSpice  AllSpice_keyshots  Brad ADR ref  Rocket  TO_003  TO_005  \
#   abt1080         1                  1             1       1       1       0
#   abt1160         1                  0             1       0       1       0
#   abt1180         1                  0             1       1       0       1
#
#            Team_A  beat_1  keyshot       cost
#   abt1080       1       1        1  35.329167
#   abt1160       0       1        0   2.125000
#   abt1180       1       1        0  18.125000  ,
#                      AllSpice  AllSpice_keyshots  Brad ADR ref    Rocket  \
#   AllSpice                NaN                NaN           NaN       NaN
#   AllSpice_keyshots       NaN           1.000000           NaN  0.500000
#   Brad ADR ref            NaN                NaN           NaN       NaN
#   Rocket                  NaN           0.500000           NaN  1.000000
#   TO_003                  NaN           0.500000           NaN -0.500000
#   TO_005                  NaN          -0.500000           NaN  0.500000
#   Team_A                  NaN           0.500000           NaN  1.000000
#   beat_1                  NaN                NaN           NaN       NaN
#   keyshot                 NaN           1.000000           NaN  0.500000
#   cost                    NaN           0.876302           NaN  0.855369
#
#                        TO_003    TO_005    Team_A  beat_1   keyshot      cost
#   AllSpice                NaN       NaN       NaN     NaN       NaN       NaN
#   AllSpice_keyshots  0.500000 -0.500000  0.500000     NaN  1.000000  0.876302
#   Brad ADR ref            NaN       NaN       NaN     NaN       NaN       NaN
#   Rocket            -0.500000  0.500000  1.000000     NaN  0.500000  0.855369
#   TO_003             1.000000 -1.000000 -0.500000     NaN  0.500000  0.020933
#   TO_005            -1.000000  1.000000  0.500000     NaN -0.500000 -0.020933
#   Team_A            -0.500000  0.500000  1.000000     NaN  0.500000  0.855369
#   beat_1                  NaN       NaN       NaN     NaN       NaN       NaN
#   keyshot            0.500000 -0.500000  0.500000     NaN  1.000000  0.876302
#   cost               0.020933 -0.020933  0.855369     NaN  0.876302  1.000000  ),
#  ('sg_cut_out',          sg_cut_out       cost
#   abt1080        1687  35.329167
#   abt1160        1089   2.125000
#   abt1180        1182  18.125000,             sg_cut_out      cost
#   sg_cut_out    1.000000  0.936722
#   cost          0.936722  1.000000),
#  ('sg_script_location',
#            Sc 35 Cam D  Sc 35D Cam D  Sc 35F Cam D       cost
#   abt1080            1             0             0  35.329167
#   abt1160            0             1             0   2.125000
#   abt1180            0             0             1  18.125000,
#                 Sc 35 Cam D  Sc 35D Cam D  Sc 35F Cam D      cost
#   Sc 35 Cam D      1.000000     -0.500000     -0.500000  0.876302
#   Sc 35D Cam D    -0.500000      1.000000     -0.500000 -0.855369
#   Sc 35F Cam D    -0.500000     -0.500000      1.000000 -0.020933
#   cost             0.876302     -0.855369     -0.020933  1.000000),
#  ('sg_editorial_grade',
#            abt1080_plates_mp_v0001  abt1160_plates_mp_v0001  \
#   abt1080                        1                        0
#   abt1160                        0                        1
#   abt1180                        0                        0
#
#            abt1180_plates_mp_v0001       cost
#   abt1080                        0  35.329167
#   abt1160                        0   2.125000
#   abt1180                        1  18.125000  ,
#                            abt1080_plates_mp_v0001  abt1160_plates_mp_v0001  \
#   abt1080_plates_mp_v0001                 1.000000                -0.500000
#   abt1160_plates_mp_v0001                -0.500000                 1.000000
#   abt1180_plates_mp_v0001                -0.500000                -0.500000
#   cost                                    0.876302                -0.855369
#
#                            abt1180_plates_mp_v0001      cost
#   abt1080_plates_mp_v0001                -0.500000  0.876302
#   abt1160_plates_mp_v0001                -0.500000 -0.855369
#   abt1180_plates_mp_v0001                 1.000000 -0.020933
#   cost                                   -0.020933  1.000000  ),
#  ('sg_working_duration',          sg_working_duration       cost
#   abt1080                  695  35.329167
#   abt1160                   97   2.125000
#   abt1180                  190  18.125000,                      sg_working_duration      cost
#   sg_working_duration             1.000000  0.936722
#   cost                            0.936722  1.000000),
#  ('sg_disk_status',          act  na       cost
#   abt1080    0   1  35.329167
#   abt1160    0   1   2.125000
#   abt1180    1   0  18.125000,            act        na      cost
#   act   1.000000 -1.000000 -0.020933
#   na   -1.000000  1.000000  0.020933
#   cost -0.020933  0.020933  1.000000),
#  ('sg_vfx_description',
#            antennae  benetar  cg  clean  color  comp  cosmetic  costume  drax  \
#   abt1080         1        1   1      0      1     1         0        1     1
#   abt1160         0        1   1      1      0     1         0        0     0
#   abt1180         0        1   1      1      0     1         1        0     0
#
#            environment    ...      rocket  seatbelts  set  space  teen  up  \
#   abt1080            1    ...           1          1    1      1     1   0
#   abt1160            0    ...           1          1    1      0     1   1
#   abt1180            0    ...           1          1    0      0     0   1
#
#            video  wig  windshield       cost
#   abt1080      1    1           1  35.329167
#   abt1160      1    0           1   2.125000
#   abt1180      0    1           0  18.125000
#
#   [3 rows x 40 columns],
#                antennae  benetar  cg     clean     color  comp  cosmetic  \
#   antennae     1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   benetar           NaN      NaN NaN       NaN       NaN   NaN       NaN
#   cg                NaN      NaN NaN       NaN       NaN   NaN       NaN
#   clean       -1.000000      NaN NaN  1.000000 -1.000000   NaN  0.500000
#   color        1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   comp              NaN      NaN NaN       NaN       NaN   NaN       NaN
#   cosmetic    -0.500000      NaN NaN  0.500000 -0.500000   NaN  1.000000
#   costume      1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   drax         1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   environment  1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   extension         NaN      NaN NaN       NaN       NaN   NaN       NaN
#   eyelid       1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   eyes         1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   fix          0.500000      NaN NaN -0.500000  0.500000   NaN  0.500000
#   fixes        1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   fx                NaN      NaN NaN       NaN       NaN   NaN       NaN
#   game         0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   gamora       1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   glass        0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   graphics     1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   groot        0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   gs                NaN      NaN NaN       NaN       NaN   NaN       NaN
#   handheld     0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   interactive       NaN      NaN NaN       NaN       NaN   NaN       NaN
#   jump         1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   light             NaN      NaN NaN       NaN       NaN   NaN       NaN
#   mantis       1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   paint       -1.000000      NaN NaN  1.000000 -1.000000   NaN  0.500000
#   quill        0.500000      NaN NaN -0.500000  0.500000   NaN  0.500000
#   raccoon      0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   rocket            NaN      NaN NaN       NaN       NaN   NaN       NaN
#   seatbelts         NaN      NaN NaN       NaN       NaN   NaN       NaN
#   set          0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   space        1.000000      NaN NaN -1.000000  1.000000   NaN -0.500000
#   teen         0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   up          -1.000000      NaN NaN  1.000000 -1.000000   NaN  0.500000
#   video        0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   wig          0.500000      NaN NaN -0.500000  0.500000   NaN  0.500000
#   windshield   0.500000      NaN NaN -0.500000  0.500000   NaN -1.000000
#   cost         0.876302      NaN NaN -0.876302  0.876302   NaN -0.020933
#
#                 costume      drax  environment    ...     rocket  seatbelts  \
#   antennae     1.000000  1.000000     1.000000    ...        NaN        NaN
#   benetar           NaN       NaN          NaN    ...        NaN        NaN
# ...
#  ('sg_camera_lens_mm',          135mm (UP135-02)  50mm (UP50-01)       cost
#   abt1080                 0               1  35.329167
#   abt1160                 1               0   2.125000
#   abt1180                 1               0  18.125000,                   135mm (UP135-02)  50mm (UP50-01)      cost
#   135mm (UP135-02)          1.000000       -1.000000 -0.876302
#   50mm (UP50-01)           -1.000000        1.000000  0.876302
#   cost                     -0.876302        0.876302  1.000000),
#  ('type',          Shot       cost
#   abt1080     1  35.329167
#   abt1160     1   2.125000
#   abt1180     1  18.125000,       Shot  cost
#   Shot   NaN   NaN
#   cost   NaN   1.0),
#  ('sg_turnover_date',          2017-05-04  2017-08-02       cost
#   abt1080           1           0  35.329167
#   abt1160           1           0   2.125000
#   abt1180           0           1  18.125000,             2017-05-04  2017-08-02      cost
#   2017-05-04    1.000000   -1.000000  0.020933
#   2017-08-02   -1.000000    1.000000 -0.020933
#   cost          0.020933   -0.020933  1.000000),
#  ('sg_bid_note',
#            adolescent  and  are  because  blank  but  cheddar  cheese  doing  \
#   abt1080           1    1    0        0      0    0        0       0      0
#   abt1160           0    0    1        0      1    1        0       0      1
#   abt1180           0    1    1        1      0    1        1       1      1
#
#            drax    ...      that  their  uh  us  video  we  whoever  why  will  \
#   abt1080     1    ...         0      1   0   0      1   0        0    0     0
#   abt1160     0    ...         1      0   1   0      0   1        0    1     0
#   abt1180     0    ...         1      0   0   1      0   1        1    1     1
#
#                 cost
#   abt1080  35.329167
#   abt1160   2.125000
#   abt1180  18.125000
#
#   [3 rows x 45 columns],
#               adolescent       and       are   because     blank       but  \
#   adolescent    1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   and           0.500000  1.000000 -0.500000  0.500000 -1.000000 -0.500000
#   are          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   because      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   blank        -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
#   but          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   cheddar      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   cheese       -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   doing        -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   drax          1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   efforts      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   flight        1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   for          -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   game          1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   gamora        1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   get          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   give         -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   groot         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   handheld      1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   huh          -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
#   in            1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   is           -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   it           -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   little       -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   mantis        1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   maybe        -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   nice         -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   our          -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   plays         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   quill         0.500000  1.000000 -0.500000  0.500000 -1.000000 -0.500000
#   re           -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   rocket             NaN       NaN       NaN       NaN       NaN       NaN
#   seats         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   sit           1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   stares       -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
#   that         -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   their         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   uh           -0.500000 -1.000000  0.500000 -0.500000  1.000000  0.500000
#   us           -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   video         1.000000  0.500000 -1.000000 -0.500000 -0.500000 -1.000000
#   we           -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   whoever      -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   why          -1.000000 -0.500000  1.000000  0.500000  0.500000  1.000000
#   will         -0.500000  0.500000  0.500000  1.000000 -0.500000  0.500000
#   cost          0.876302  0.855369 -0.876302 -0.020933 -0.855369 -0.876302
#
#                cheddar    cheese     doing      drax    ...         that  \
#   adolescent -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   and         0.500000  0.500000 -0.500000  0.500000    ...    -0.500000
#   are         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   because     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   blank      -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
#   but         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   cheddar     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   cheese      1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   doing       0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   drax       -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   efforts     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   flight     -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   for         1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   game       -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   gamora     -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   get         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   give        1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   groot      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   handheld   -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   huh        -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
#   in         -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   is          1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   it          0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   little      1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   mantis     -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   maybe       1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   nice        1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   our         1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   plays      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   quill       0.500000  0.500000 -0.500000  0.500000    ...    -0.500000
#   re          1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   rocket           NaN       NaN       NaN       NaN    ...          NaN
#   seats      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   sit        -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   stares     -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
#   that        0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   their      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   uh         -0.500000 -0.500000  0.500000 -0.500000    ...     0.500000
#   us          1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   video      -0.500000 -0.500000 -1.000000  1.000000    ...    -1.000000
#   we          0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   whoever     1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   why         0.500000  0.500000  1.000000 -1.000000    ...     1.000000
#   will        1.000000  1.000000  0.500000 -0.500000    ...     0.500000
#   cost       -0.020933 -0.020933 -0.876302  0.876302    ...    -0.876302
#
#                  their        uh        us     video        we   whoever  \
#   adolescent  1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   and         0.500000 -1.000000  0.500000  0.500000 -0.500000  0.500000
#   are        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   because    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   blank      -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
#   but        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   cheddar    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   cheese     -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   doing      -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   drax        1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   efforts    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   flight      1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   for        -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   game        1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   gamora      1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   get        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   give       -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   groot       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   handheld    1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   huh        -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
#   in          1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   is         -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   it         -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   little     -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   mantis      1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   maybe      -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   nice       -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   our        -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   plays       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   quill       0.500000 -1.000000  0.500000  0.500000 -0.500000  0.500000
#   re         -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   rocket           NaN       NaN       NaN       NaN       NaN       NaN
#   seats       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   sit         1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   stares     -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
#   that       -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   their       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   uh         -0.500000  1.000000 -0.500000 -0.500000  0.500000 -0.500000
#   us         -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   video       1.000000 -0.500000 -0.500000  1.000000 -1.000000 -0.500000
#   we         -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   whoever    -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   why        -1.000000  0.500000  0.500000 -1.000000  1.000000  0.500000
#   will       -0.500000 -0.500000  1.000000 -0.500000  0.500000  1.000000
#   cost        0.876302 -0.855369 -0.020933  0.876302 -0.876302 -0.020933
#
#                    why      will      cost
#   adolescent -1.000000 -0.500000  0.876302
#   and        -0.500000  0.500000  0.855369
#   are         1.000000  0.500000 -0.876302
#   because     0.500000  1.000000 -0.020933
#   blank       0.500000 -0.500000 -0.855369
#   but         1.000000  0.500000 -0.876302
#   cheddar     0.500000  1.000000 -0.020933
#   cheese      0.500000  1.000000 -0.020933
#   doing       1.000000  0.500000 -0.876302
#   drax       -1.000000 -0.500000  0.876302
#   efforts     0.500000  1.000000 -0.020933
#   flight     -1.000000 -0.500000  0.876302
#   for         0.500000  1.000000 -0.020933
#   game       -1.000000 -0.500000  0.876302
#   gamora     -1.000000 -0.500000  0.876302
#   get         1.000000  0.500000 -0.876302
#   give        0.500000  1.000000 -0.020933
#   groot      -1.000000 -0.500000  0.876302
#   handheld   -1.000000 -0.500000  0.876302
#   huh         0.500000 -0.500000 -0.855369
#   in         -1.000000 -0.500000  0.876302
#   is          0.500000  1.000000 -0.020933
#   it          1.000000  0.500000 -0.876302
#   little      0.500000  1.000000 -0.020933
#   mantis     -1.000000 -0.500000  0.876302
#   maybe       0.500000  1.000000 -0.020933
#   nice        0.500000  1.000000 -0.020933
#   our         0.500000  1.000000 -0.020933
#   plays      -1.000000 -0.500000  0.876302
#   quill      -0.500000  0.500000  0.855369
#   re          0.500000  1.000000 -0.020933
#   rocket           NaN       NaN       NaN
#   seats      -1.000000 -0.500000  0.876302
#   sit        -1.000000 -0.500000  0.876302
#   stares      0.500000 -0.500000 -0.855369
#   that        1.000000  0.500000 -0.876302
#   their      -1.000000 -0.500000  0.876302
#   uh          0.500000 -0.500000 -0.855369
#   us          0.500000  1.000000 -0.020933
#   video      -1.000000 -0.500000  0.876302
#   we          1.000000  0.500000 -0.876302
#   whoever     0.500000  1.000000 -0.020933
#   why         1.000000  0.500000 -0.876302
#   will        0.500000  1.000000 -0.020933
#   cost       -0.876302 -0.020933  1.000000
#
#   [45 rows x 45 columns]),
#  ('sg_good_for_temp',         sg_good_for_temp       cost
#   abt1080                0  35.329167
#   abt1160                0   2.125000
#   abt1180             True  18.125000,       cost
#   cost   1.0),
#  ('project',          Mary Lou       cost
#   abt1080         1  35.329167
#   abt1160         1   2.125000
#   abt1180         1  18.125000,           Mary Lou  cost
#   Mary Lou       NaN   NaN
#   cost           NaN   1.0),
#  ('sg_reel',          2       cost
#   abt1080  1  35.329167
#   abt1160  0   2.125000
#   abt1180  1  18.125000,              2      cost
#   2     1.000000  0.855369
#   cost  0.855369  1.000000),
#  ('sg_assigned_to',          Mark Derksen       cost
#   abt1080             0  35.329167
#   abt1160             0   2.125000
#   abt1180             1  18.125000,               Mark Derksen      cost
#   Mark Derksen      1.000000 -0.020933
#   cost             -0.020933  1.000000),
#  ('sg_tail_handle',          sg_tail_handle       cost
#   abt1080               8  35.329167
#   abt1160               8   2.125000
#   abt1180               8  18.125000,                 sg_tail_handle  cost
#   sg_tail_handle             NaN   NaN
#   cost                       NaN   1.0),
#  ('sg_primary_location',          Los Angeles       cost
#   abt1080            1  35.329167
#   abt1160            1   2.125000
#   abt1180            1  18.125000,              Los Angeles  cost
#   Los Angeles          NaN   NaN
#   cost                 NaN   1.0)]

# %%
from lib.model.linear_regression.model import LinearRegression

# %%
linear_regression = LinearRegression(df_all['df_x_full'], df_all['df_y_full'])

# %%
linear_regression.fit()
# Out:
# {'mean_squared_error': 1097.4429948537311,
#  'predictor': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)}
